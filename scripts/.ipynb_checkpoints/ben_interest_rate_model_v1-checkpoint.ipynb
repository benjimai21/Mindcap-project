# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.metrics import confusion_matrix, multilabel_confusion_matrix, roc_curve, recall_score
from math import sqrt, log
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import RidgeClassifier
import graphviz

from sklearn.tree import tree, export_graphviz, DecisionTreeClassifier
from sklearn import tree
from matplotlib import pyplot as plt
from IPython.display import Image, display
from sklearn.utils import class_weight
# %matplotlib inline
plt.style.use('ggplot')
SEED = 42

pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv("LoanStats3d_securev1 2.csv")
#df2 = pd.read_excel("LCDataDictionary (1).xlsx")
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (19,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head(10)
#loan_amnt: application
#funded_amnt: total amount given 
#funded_amnt_inv: amount given by the investors (case in which investors provide a part and investors)

#the platform may decide or not to allocate
#grade: A is best and F the worst 
#subgrade: Within the grade different levels
#term: how long
#interest rate per month: based on the remaining balance
#emp_length: for how long they work for the employer
#annual income
#verification_status: whether the income was checked
#issues date of the loan issue:
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  10224583        NaN    11100.0      11100.0          11100.0   36 months
# 1  10148122        NaN    12000.0      12000.0          12000.0   36 months
# 2  10149342        NaN    27050.0      27050.0          27050.0   36 months
# 3  10129454        NaN    12000.0      12000.0          12000.0   36 months
# 4  10149488        NaN     4800.0       4800.0           4800.0   36 months
# 5  10159498        NaN    12000.0      12000.0          12000.0   36 months
# 6  10129477        NaN    14000.0      14000.0          14000.0   36 months
# 7  10159548        NaN    15000.0      15000.0          15000.0   36 months
# 8  10129403        NaN     7550.0       7550.0           7550.0   36 months
# 9  10119623        NaN    12000.0      12000.0          12000.0   36 months
#
#   int_rate  installment grade sub_grade                             emp_title  \
# 0   14.98%       384.68     C        C3                               Teacher
# 1    7.62%       373.94     A        A3                      Systems Engineer
# 2   10.99%       885.46     B        B2   Team Leadern Customer Ops & Systems
# 3   10.99%       392.81     B        B2                       Project Manager
# 4   10.99%       157.13     B        B2                   Surgical Technician
# 5    6.62%       368.45     A        A2          MANAGER INFORMATION DELIVERY
# 6   12.85%       470.71     B        B4  Assistant Director - Human Resources
# 7    8.90%       476.30     A        A5         aircraft maintenance engineer
# 8   16.24%       266.34     C        C5       Special Order Fulfillment Clerk
# 9   11.99%       398.52     B        B3                                   LTC
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0  10+ years       MORTGAGE     90000.0        Not Verified  Dec-2013
# 1    3 years       MORTGAGE     96500.0        Not Verified  Dec-2013
# 2  10+ years            OWN     55000.0            Verified  Dec-2013
# 3    4 years           RENT     60000.0        Not Verified  Dec-2013
# 4    2 years       MORTGAGE     39600.0     Source Verified  Dec-2013
# 5  10+ years       MORTGAGE    105000.0        Not Verified  Dec-2013
# 6    4 years           RENT     88000.0        Not Verified  Dec-2013
# 7    2 years       MORTGAGE     63000.0        Not Verified  Dec-2013
# 8    3 years           RENT     28000.0        Not Verified  Dec-2013
# 9  10+ years       MORTGAGE    130000.0     Source Verified  Dec-2013
#
#   loan_status pymnt_plan                                                url  \
# 0  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 1  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 2  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 3  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 4  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 5  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 6  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 7  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 8  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 9  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
#
#                                                 desc             purpose  \
# 0                                                NaN               other
# 1    Borrower added on 12/31/13 > Bought a new ho...  debt_consolidation
# 2    Borrower added on 12/31/13 > Combining high ...  debt_consolidation
# 3    Borrower added on 12/31/13 > I would like to...  debt_consolidation
# 4    Borrower added on 12/31/13 > Just bought a h...    home_improvement
# 5                                                NaN  debt_consolidation
# 6                                                NaN  debt_consolidation
# 7    Borrower added on 12/31/13 > To pay Home Dep...  debt_consolidation
# 8                                                NaN  debt_consolidation
# 9                                                NaN  debt_consolidation
#
#                                     title zip_code addr_state    dti  \
# 0                                   Other    103xx         NY   3.73
# 1  Debt Consolidation and Credit Transfer    782xx         TX  12.61
# 2                      Debt Consolidation    481xx         MI  22.87
# 3                              No Regrets    281xx         NC   4.62
# 4                           For The House    782xx         TX   2.49
# 5                          UNIVERSAL CARD    060xx         CT  14.05
# 6                      Debt consolidation    282xx         NC  10.02
# 7                                 Pay off    334xx         FL  16.51
# 8                      Debt consolidation    951xx         CA   8.40
# 9                      Debt consolidation    809xx         CO  13.03
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          1.0         Jun-2001           690.0            694.0
# 1          0.0         Sep-2003           705.0            709.0
# 2          0.0         Oct-1986           730.0            734.0
# 3          0.0         Dec-2009           720.0            724.0
# 4          0.0         Aug-1995           755.0            759.0
# 5          0.0         Mar-1994           760.0            764.0
# 6          1.0         Jun-1988           670.0            674.0
# 7          0.0         Mar-1998           670.0            674.0
# 8          0.0         Oct-2010           660.0            664.0
# 9          0.0         Nov-1997           715.0            719.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             0.0                    16.0                     NaN       9.0
# 1             0.0                     NaN                     NaN      17.0
# 2             0.0                     NaN                     NaN      14.0
# 3             1.0                     NaN                     NaN      15.0
# 4             2.0                     NaN                     NaN       3.0
# 5             1.0                    43.0                     NaN      12.0
# 6             0.0                    16.0                   115.0       6.0
# 7             0.0                    34.0                     NaN       8.0
# 8             0.0                     NaN                     NaN       4.0
# 9             1.0                     NaN                     NaN       9.0
#
#    pub_rec  revol_bal revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0     6619.0      66.2%       12.0                   f        0.0
# 1      0.0    13248.0      55.7%       30.0                   f        0.0
# 2      0.0    36638.0      61.2%       27.0                   w        0.0
# 3      0.0     7137.0        24%       18.0                   f        0.0
# 4      0.0     4136.0      16.1%        8.0                   w        0.0
# 5      0.0    13168.0      21.6%       22.0                   w        0.0
# 6      1.0     3686.0      81.9%       14.0                   f        0.0
# 7      0.0    11431.0      74.2%       29.0                   w        0.0
# 8      0.0     5759.0        72%        5.0                   w        0.0
# 9      0.0    10805.0        67%       19.0                   f        0.0
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0            0.0  13575.640006         13575.64          11100.0
# 1            0.0  13397.539998         13397.54          12000.0
# 2            0.0  31752.530000         31752.53          27050.0
# 3            0.0  13988.609996         13988.61          12000.0
# 4            0.0   5157.519457          5157.52           4800.0
# 5            0.0  13263.954639         13263.95          12000.0
# 6            0.0  16945.318783         16945.32          14000.0
# 7            0.0  17146.725104         17146.73          15000.0
# 8            0.0   9600.454631          9600.45           7550.0
# 9            0.0  14346.479050         14346.48          12000.0
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0        2475.64                 0.0         0.0                      0.0
# 1        1397.54                 0.0         0.0                      0.0
# 2        4702.53                 0.0         0.0                      0.0
# 3        1988.61                 0.0         0.0                      0.0
# 4         357.52                 0.0         0.0                      0.0
# 5        1263.95                 0.0         0.0                      0.0
# 6        2945.32                 0.0         0.0                      0.0
# 7        2146.73                 0.0         0.0                      0.0
# 8        2050.45                 0.0         0.0                      0.0
# 9        2346.48                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt  next_pymnt_d last_credit_pull_d  \
# 0     Feb-2016          4343.32           NaN           Jun-2018
# 1     Jun-2016          2927.22           NaN           Mar-2020
# 2     Jul-2016          6074.19           NaN           Mar-2020
# 3     Apr-2016          3775.55           NaN           Aug-2018
# 4     Sep-2014          3900.48           NaN           Jan-2017
# 5     Jan-2017           368.20           NaN           Mar-2020
# 6     Jan-2017           470.47           NaN           Mar-2020
# 7     Jan-2017           476.23           NaN           Mar-2020
# 8     Dec-2016           529.67           NaN           May-2019
# 9     Jan-2017           398.28           NaN           Jul-2018
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 779.0                775.0                         0.0
# 1                 809.0                805.0                         0.0
# 2                 834.0                830.0                         0.0
# 3                 569.0                565.0                         0.0
# 4                 534.0                530.0                         0.0
# 5                 774.0                770.0                         0.0
# 6                 544.0                540.0                         0.0
# 7                 749.0                745.0                         0.0
# 8                 634.0                630.0                         0.0
# 9                 714.0                710.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                         16.0          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0       Individual
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
# 5                          NaN          1.0       Individual
# 6                          NaN          1.0       Individual
# 7                         34.0          1.0       Individual
# 8                          NaN          1.0       Individual
# 9                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint  verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                        NaN             0.0
# 1               NaN        NaN                        NaN             0.0
# 2               NaN        NaN                        NaN             0.0
# 3               NaN        NaN                        NaN             0.0
# 4               NaN        NaN                        NaN             0.0
# 5               NaN        NaN                        NaN             0.0
# 6               NaN        NaN                        NaN             0.0
# 7               NaN        NaN                        NaN             0.0
# 8               NaN        NaN                        NaN             0.0
# 9               NaN        NaN                        NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0           0.0     353402.0          NaN          NaN          NaN
# 1           0.0     200314.0          NaN          NaN          NaN
# 2           0.0     114834.0          NaN          NaN          NaN
# 3           0.0       7137.0          NaN          NaN          NaN
# 4           0.0       4136.0          NaN          NaN          NaN
# 5           0.0     267646.0          NaN          NaN          NaN
# 6           0.0      17672.0          NaN          NaN          NaN
# 7        1514.0     272492.0          NaN          NaN          NaN
# 8           0.0       5759.0          NaN          NaN          NaN
# 9           0.0     327264.0          NaN          NaN          NaN
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          NaN                 NaN           NaN      NaN          NaN
# 1          NaN                 NaN           NaN      NaN          NaN
# 2          NaN                 NaN           NaN      NaN          NaN
# 3          NaN                 NaN           NaN      NaN          NaN
# 4          NaN                 NaN           NaN      NaN          NaN
# 5          NaN                 NaN           NaN      NaN          NaN
# 6          NaN                 NaN           NaN      NaN          NaN
# 7          NaN                 NaN           NaN      NaN          NaN
# 8          NaN                 NaN           NaN      NaN          NaN
# 9          NaN                 NaN           NaN      NaN          NaN
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          NaN         NaN       NaN           10000.0     NaN          NaN
# 1          NaN         NaN       NaN           23800.0     NaN          NaN
# 2          NaN         NaN       NaN           59900.0     NaN          NaN
# 3          NaN         NaN       NaN           29700.0     NaN          NaN
# 4          NaN         NaN       NaN           25700.0     NaN          NaN
# 5          NaN         NaN       NaN           61100.0     NaN          NaN
# 6          NaN         NaN       NaN            4500.0     NaN          NaN
# 7          NaN         NaN       NaN           15400.0     NaN          NaN
# 8          NaN         NaN       NaN            8000.0     NaN          NaN
# 9          NaN         NaN       NaN           16200.0     NaN          NaN
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           NaN                   2.0      39267.0          1016.0     74.6
# 1           NaN                   4.0      11783.0          2441.0     83.5
# 2           NaN                   3.0       9570.0         16473.0     53.9
# 3           NaN                   8.0        476.0         15216.0     15.9
# 4           NaN                   0.0       1379.0         21564.0     16.1
# 5           NaN                   4.0      26765.0         39432.0     25.0
# 6           NaN                   3.0       2945.0           480.0     87.7
# 7           NaN                   3.0      38927.0          2969.0     79.1
# 8           NaN                   1.0       1440.0           160.0     96.0
# 9           NaN                   4.0      36362.0          3567.0     93.0
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0                 NaN
# 1                       0.0          0.0               123.0
# 2                       0.0          0.0               117.0
# 3                       0.0          0.0                 NaN
# 4                       0.0          0.0               104.0
# 5                       0.0          0.0               146.0
# 6                       0.0          0.0               111.0
# 7                       0.0          0.0               147.0
# 8                       0.0          0.0                 NaN
# 9                       0.0          0.0               173.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 150.0                   11.0            11.0       1.0
# 1                 118.0                   10.0             9.0       1.0
# 2                 326.0                   16.0             6.0       4.0
# 3                  48.0                    1.0             1.0       0.0
# 4                 220.0                   25.0            25.0       0.0
# 5                 237.0                   20.0             3.0       4.0
# 6                 103.0                   24.0            13.0       0.0
# 7                 189.0                   24.0            13.0       4.0
# 8                  38.0                   17.0            17.0       0.0
# 9                 193.0                    4.0             4.0       3.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                  11.0                      35.0                   11.0
# 1                  10.0                       NaN                   10.0
# 2                  16.0                       NaN                    8.0
# 3                   1.0                       NaN                    3.0
# 4                  25.0                       NaN                    3.0
# 5                  20.0                       NaN                    3.0
# 6                  38.0                      16.0                    NaN
# 7                  24.0                      75.0                   12.0
# 8                  17.0                       NaN                   17.0
# 9                  85.0                       NaN                    4.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            35.0                    1.0             4.0
# 1                             NaN                    0.0             4.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             4.0
# 4                             NaN                    0.0             2.0
# 5                            43.0                    0.0             2.0
# 6                            16.0                    0.0             3.0
# 7                            75.0                    3.0             3.0
# 8                             NaN                    0.0             2.0
# 9                             NaN                    0.0             3.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              8.0          4.0        4.0        0.0            8.0
# 1              5.0          4.0       10.0       15.0            8.0
# 2              4.0          4.0        8.0        8.0           10.0
# 3              7.0          8.0       10.0        0.0           15.0
# 4              2.0          3.0        4.0        1.0            3.0
# 5              2.0          5.0        5.0        9.0            8.0
# 6              4.0          3.0        9.0        3.0            4.0
# 7              4.0          3.0       10.0        8.0            6.0
# 8              4.0          2.0        2.0        0.0            4.0
# 9              5.0          4.0        4.0        8.0            5.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0           11.0                  8.0       9.0               0.0
# 1           14.0                  5.0      17.0               0.0
# 2           15.0                  4.0      14.0               0.0
# 3           18.0                  7.0      15.0               0.0
# 4            7.0                  2.0       3.0               0.0
# 5            9.0                  2.0      12.0               0.0
# 6           10.0                  4.0       6.0               0.0
# 7           17.0                  4.0       8.0               0.0
# 8            5.0                  4.0       4.0               0.0
# 9            8.0                  5.0       9.0               NaN
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 1.0                 1.0            75.0
# 1           0.0                 0.0                 3.0           100.0
# 2           0.0                 0.0                 1.0           100.0
# 3           0.0                 0.0                 4.0           100.0
# 4           0.0                 0.0                 0.0           100.0
# 5           0.0                 0.0                 2.0            95.5
# 6           0.0                 0.0                 0.0            78.6
# 7           0.0                 0.0                 0.0            89.3
# 8           0.0                 0.0                 0.0           100.0
# 9           0.0                 0.0                 3.0           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0              50.0                   0.0        0.0         385000.0
# 1             100.0                   0.0        0.0         233004.0
# 2              25.0                   0.0        0.0         138554.0
# 3               0.0                   0.0        0.0          29700.0
# 4               0.0                   0.0        0.0          25700.0
# 5               0.0                   0.0        0.0         333044.0
# 6             100.0                   1.0        0.0          31840.0
# 7              66.7                   0.0        0.0         288195.0
# 8             100.0                   0.0        0.0           8000.0
# 9               1.0                   0.0        0.0         365874.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             6619.0          4000.0                         0.0
# 1            46738.0         14800.0                     53404.0
# 2            70186.0         35700.0                     33054.0
# 3             7137.0         18100.0                         0.0
# 4             4136.0         25700.0                         0.0
# 5            42603.0         52600.0                     42769.0
# 6            17672.0          3900.0                     27340.0
# 7            39448.0         14200.0                     33895.0
# 8             5759.0          4000.0                         0.0
# 9            44327.0         10700.0                     57674.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
# 5              NaN                     NaN                      NaN
# 6              NaN                     NaN                      NaN
# 7              NaN                     NaN                      NaN
# 8              NaN                     NaN                      NaN
# 9              NaN                     NaN                      NaN
#
#    sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                       NaN                     NaN               NaN
# 1                       NaN                     NaN               NaN
# 2                       NaN                     NaN               NaN
# 3                       NaN                     NaN               NaN
# 4                       NaN                     NaN               NaN
# 5                       NaN                     NaN               NaN
# 6                       NaN                     NaN               NaN
# 7                       NaN                     NaN               NaN
# 8                       NaN                     NaN               NaN
# 9                       NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
# 5               NaN                 NaN                  NaN
# 6               NaN                 NaN                  NaN
# 7               NaN                 NaN                  NaN
# 8               NaN                 NaN                  NaN
# 9               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
# 5                    NaN                               NaN
# 6                    NaN                               NaN
# 7                    NaN                               NaN
# 8                    NaN                               NaN
# 9                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
# 5                                 NaN                                  NaN
# 6                                 NaN                                  NaN
# 7                                 NaN                                  NaN
# 8                                 NaN                                  NaN
# 9                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
# 5             N           NaN             NaN             NaN            NaN
# 6             N           NaN             NaN             NaN            NaN
# 7             N           NaN             NaN             NaN            NaN
# 8             N           NaN             NaN             NaN            NaN
# 9             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
# 5              NaN                 NaN               NaN
# 6              NaN                 NaN               NaN
# 7              NaN                 NaN               NaN
# 8              NaN                 NaN               NaN
# 9              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
# 5                     NaN              NaN           NaN                  NaN
# 6                     NaN              NaN           NaN                  NaN
# 7                     NaN              NaN           NaN                  NaN
# 8                     NaN              NaN           NaN                  NaN
# 9                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
# 5                                         NaN                             NaN
# 6                                         NaN                             NaN
# 7                                         NaN                             NaN
# 8                                         NaN                             NaN
# 9                                         NaN                             NaN
#
#    hardship_last_payment_amount debt_settlement_flag  \
# 0                           NaN                    N
# 1                           NaN                    N
# 2                           NaN                    N
# 3                           NaN                    N
# 4                           NaN                    N
# 5                           NaN                    N
# 6                           NaN                    N
# 7                           NaN                    N
# 8                           NaN                    N
# 9                           NaN                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
# 5                       NaN               NaN             NaN
# 6                       NaN               NaN             NaN
# 7                       NaN               NaN             NaN
# 8                       NaN               NaN             NaN
# 9                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN
# 5                NaN                    NaN              NaN
# 6                NaN                    NaN              NaN
# 7                NaN                    NaN              NaN
# 8                NaN                    NaN              NaN
# 9                NaN                    NaN              NaN

# %%
df[(df["sub_grade"] == "C4") & (df["int_rate"] == " 13.99%")]
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 1       68367011        NaN      21000        21000          21000.0
# 2       68615044        NaN      16000        16000          16000.0
# 16      68356922        NaN       4200         4200           4200.0
# 27      68506862        NaN      20000        20000          20000.0
# 52      68585839        NaN      17475        17475          17475.0
# ...          ...        ...        ...          ...              ...
# 377288  40384222        NaN       6000         6000           6000.0
# 377315  40503777        NaN      21000        21000          21000.0
# 377337  40356285        NaN      10000        10000          10000.0
# 377432  40736128        NaN      20000        20000          20000.0
# 377449  40443903        NaN      20000        20000          20000.0
#
#               term int_rate  installment grade sub_grade  \
# 1        60 months   13.99%       488.53     C        C4
# 2        60 months   13.99%       372.21     C        C4
# 16       36 months   13.99%       143.53     C        C4
# 27       60 months   13.99%       465.27     C        C4
# 52       36 months   13.99%       597.17     C        C4
# ...            ...      ...          ...   ...       ...
# 377288   36 months   13.99%       205.04     C        C4
# 377315   36 months   13.99%       717.63     C        C4
# 377337   60 months   13.99%       232.64     C        C4
# 377432   60 months   13.99%       465.27     C        C4
# 377449   60 months   13.99%       465.27     C        C4
#
#                        emp_title emp_length home_ownership  annual_inc  \
# 1             Resident physician   < 1 year           RENT     52000.0
# 2               Registered Nurse    9 years       MORTGAGE    142000.0
# 16                Patrol Officer    2 years           RENT     32000.0
# 27        Facilities Coordinator  10+ years            OWN     70000.0
# 52      Software Testing Analyst    2 years           RENT     39750.0
# ...                          ...        ...            ...         ...
# 377288            press operator  10+ years       MORTGAGE     73000.0
# 377315   Regional Sales Manager     4 years           RENT     95000.0
# 377337          Registered Nurse    5 years           RENT     55000.0
# 377432     Real Estate Executive    8 years       MORTGAGE     75000.0
# 377449        Accounting Manager  10+ years           RENT     85000.0
#
#        verification_status   issue_d         loan_status pymnt_plan  \
# 1          Source Verified  Dec-2015             Current          n
# 2                 Verified  Dec-2015             Current          n
# 16         Source Verified  Dec-2015             Current          n
# 27         Source Verified  Dec-2015  Late (31-120 days)          n
# 52            Not Verified  Dec-2015             Current          n
# ...                    ...       ...                 ...        ...
# 377288        Not Verified  Feb-2015          Fully Paid          n
# 377315     Source Verified  Feb-2015          Fully Paid          n
# 377337            Verified  Feb-2015             Current          n
# 377432     Source Verified  Feb-2015          Fully Paid          n
# 377449     Source Verified  Feb-2015             Current          n
#
#                                                       url desc  \
# 1       https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2       https://lendingclub.com/browse/loanDetail.acti...  NaN
# 16      https://lendingclub.com/browse/loanDetail.acti...  NaN
# 27      https://lendingclub.com/browse/loanDetail.acti...  NaN
# 52      https://lendingclub.com/browse/loanDetail.acti...  NaN
# ...                                                   ...  ...
# 377288  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 377315  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 377337  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 377432  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 377449  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                    purpose                    title zip_code addr_state  \
# 1              credit_card  Credit card refinancing    441xx         OH
# 2       debt_consolidation       Debt consolidation    945xx         CA
# 16                   other                    Other    377xx         TN
# 27      debt_consolidation       Debt consolidation    210xx         MD
# 52      debt_consolidation       Debt consolidation    604xx         IL
# ...                    ...                      ...      ...        ...
# 377288  debt_consolidation       Debt consolidation    370xx         TN
# 377315  debt_consolidation       Debt consolidation    306xx         GA
# 377337  debt_consolidation       Debt consolidation    303xx         GA
# 377432             medical         Medical expenses    891xx         NV
# 377449  debt_consolidation       Debt consolidation    917xx         CA
#
#           dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 1       14.47            0         Jan-2005             680              684
# 2       17.74            2         Oct-2004             680              684
# 16      31.02            0         Nov-2009             705              709
# 27      16.90            0         Jun-2001             680              684
# 52      23.58            0         May-2002             695              699
# ...       ...          ...              ...             ...              ...
# 377288  11.84            0         Mar-2004             665              669
# 377315  25.95            0         Oct-2002             685              689
# 377337  25.22            0         May-2002             690              694
# 377432  17.51            0         May-2000             670              674
# 377449  18.74            0         Oct-1994             700              704
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 1                    1                     NaN                     NaN
# 2                    2                     8.0                    39.0
# 16                   2                    50.0                     NaN
# 27                   0                    33.0                     NaN
# 52                   0                    27.0                     NaN
# ...                ...                     ...                     ...
# 377288               0                    53.0                    29.0
# 377315               0                    33.0                     NaN
# 377337               2                    38.0                     NaN
# 377432               0                     NaN                    62.0
# 377449               0                    27.0                     NaN
#
#         open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 1              5        0      20374      87.4%         15
# 2             15        2       2273      39.9%         19
# 16            10        0       1294      11.7%         16
# 27            20        0      31200        42%         35
# 52             7        0      10987      52.3%         13
# ...          ...      ...        ...        ...        ...
# 377288        11        1       2921      52.2%         29
# 377315        16        0      17643      60.8%         59
# 377337        21        0      10324      40.9%         45
# 377432        10        1      19582      57.6%         19
# 377449         4        0       4089      74.3%         26
#
#        initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 1                        w   17030.49       17030.49   7409.560000
# 2                        w   12975.66       12975.66   5552.060000
# 16                       w    2659.71        2659.71   2144.790000
# 27                       w   17034.83       17034.83   5558.020000
# 52                       w   11531.79       11531.79   8421.800000
# ...                    ...        ...            ...           ...
# 377288                   f       0.00           0.00   6790.840001
# 377315                   w       0.00           0.00  22810.810000
# 377337                   w    6498.88        6498.88   6039.290000
# 377432                   w       0.00           0.00  21728.390000
# 377449                   w   13308.19       13308.19  11616.210000
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 1               7409.56          3969.51        3440.05                 0.0
# 2               5552.06          3024.34        2527.72                 0.0
# 16              2144.79          1540.29         604.50                 0.0
# 27              5558.02          2965.17        2592.85                 0.0
# 52              8421.80          5943.21        2478.59                 0.0
# ...                 ...              ...            ...                 ...
# 377288          6790.84          6000.00         790.84                 0.0
# 377315         22810.81         21000.00        1810.81                 0.0
# 377337          6039.29          3501.12        2538.17                 0.0
# 377432         21728.39         20000.00        1728.39                 0.0
# 377449         11616.21          6691.81        4924.40                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 1              0.0                      0.0     Apr-2017           488.53
# 2              0.0                      0.0     Apr-2017           372.21
# 16             0.0                      0.0     Apr-2017           143.53
# 27             0.0                      0.0     Jan-2017           465.27
# 52             0.0                      0.0     Mar-2017           597.17
# ...            ...                      ...          ...              ...
# 377288         0.0                      0.0     Mar-2016          4335.02
# 377315         0.0                      0.0     Oct-2015         17803.72
# 377337         0.0                      0.0     Apr-2017           232.64
# 377432         0.0                      0.0     Mar-2016          4160.69
# 377449         0.0                      0.0     Mar-2017           465.27
#
#        next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 1          May-2017           Apr-2017                   674
# 2          Apr-2017           Apr-2017                   734
# 16         Apr-2017           Apr-2017                   684
# 27         May-2017           Apr-2017                   569
# 52         May-2017           Apr-2017                   704
# ...             ...                ...                   ...
# 377288          NaN           Apr-2017                   684
# 377315          NaN           Apr-2017                   649
# 377337     May-2017           Apr-2017                   639
# 377432          NaN           Apr-2016                   644
# 377449     May-2017           Apr-2017                   729
#
#         last_fico_range_low  collections_12_mths_ex_med  \
# 1                       670                           0
# 2                       730                           0
# 16                      680                           0
# 27                      565                           0
# 52                      700                           0
# ...                     ...                         ...
# 377288                  680                           0
# 377315                  645                           0
# 377337                  635                           0
# 377432                  640                           0
# 377449                  725                           0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 1                               NaN            1       INDIVIDUAL
# 2                              43.0            1       INDIVIDUAL
# 16                             60.0            1       INDIVIDUAL
# 27                             69.0            1       INDIVIDUAL
# 52                              NaN            1       INDIVIDUAL
# ...                             ...          ...              ...
# 377288                         53.0            1       INDIVIDUAL
# 377315                         33.0            1       INDIVIDUAL
# 377337                         46.0            1       INDIVIDUAL
# 377432                          NaN            1       INDIVIDUAL
# 377449                         58.0            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 1                    NaN        NaN                       NaN               0
# 2                    NaN        NaN                       NaN               0
# 16                   NaN        NaN                       NaN               0
# 27                   NaN        NaN                       NaN               0
# 52                   NaN        NaN                       NaN               0
# ...                  ...        ...                       ...             ...
# 377288               NaN        NaN                       NaN               0
# 377315               NaN        NaN                       NaN               0
# 377337               NaN        NaN                       NaN               0
# 377432               NaN        NaN                       NaN               0
# 377449               NaN        NaN                       NaN               0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 1                  0       372407          1.0         1.0          1.0
# 2                  0       667373          0.0         7.0          0.0
# 16                 0        38865          2.0         6.0          2.0
# 27                 0        34856          2.0         1.0          0.0
# 52                 0        32365          0.0         3.0          0.0
# ...              ...          ...          ...         ...          ...
# 377288          1372       112612          NaN         NaN          NaN
# 377315             0       308364          NaN         NaN          NaN
# 377337             0        95666          NaN         NaN          NaN
# 377432           276        30892          NaN         NaN          NaN
# 377449            77        18622          NaN         NaN          NaN
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 1               1.0                 5.0      352033.0      NaN          0.0
# 2               6.0                17.0      109893.0     69.0          0.0
# 16              5.0                 1.0       37571.0     89.0          1.0
# 27              0.0                43.0        3656.0     37.0          2.0
# 52              1.0                18.0       21378.0     73.0          1.0
# ...             ...                 ...           ...      ...          ...
# 377288          NaN                 NaN           NaN      NaN          NaN
# 377315          NaN                 NaN           NaN      NaN          NaN
# 377337          NaN                 NaN           NaN      NaN          NaN
# 377432          NaN                 NaN           NaN      NaN          NaN
# 377449          NaN                 NaN           NaN      NaN          NaN
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 1               0.0      9358.0      87.0             23300     1.0
# 2               1.0      1959.0      66.0              5700     5.0
# 16              2.0       173.0      73.0             11100     3.0
# 27              3.0      4367.0      41.0             74200     0.0
# 52              2.0      9131.0      64.0             21000     1.0
# ...             ...         ...       ...               ...     ...
# 377288          NaN         NaN       NaN              5600     NaN
# 377315          NaN         NaN       NaN             29000     NaN
# 377337          NaN         NaN       NaN             25272     NaN
# 377432          NaN         NaN       NaN             34000     NaN
# 377449          NaN         NaN       NaN              5500     NaN
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 1               0.0           2.0                     1        74481
# 2               0.0           3.0                     7        47670
# 16              3.0           3.0                     7         3887
# 27              1.0           0.0                     3         1835
# 52              0.0           3.0                     3         5394
# ...             ...           ...                   ...          ...
# 377288          NaN           NaN                     5        11261
# 377315          NaN           NaN                    14        20558
# 377337          NaN           NaN                     9         5035
# 377432          NaN           NaN                     2         3089
# 377449          NaN           NaN                     0         4656
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 1               2926.0     87.4                         0            0
# 2               2827.0     44.6                         0            0
# 16              5422.0      3.2                         0            0
# 27             18527.0     44.0                         0            0
# 52             10013.0     52.3                         0            0
# ...                ...      ...                       ...          ...
# 377288          1679.0     63.5                         0            0
# 377315          4255.0     51.6                         0            0
# 377337         11198.0     47.2                         0            0
# 377432         10092.0     64.0                         0            0
# 377449          1021.0     48.9                         0            0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 1                     76.0                   131                     85
# 2                    134.0                    98                     23
# 16                    73.0                    72                      6
# 27                    46.0                   174                      5
# 52                   106.0                   163                     11
# ...                    ...                   ...                    ...
# 377288               113.0                   130                      1
# 377315               148.0                    54                     14
# 377337               150.0                   153                      1
# 377432               177.0                   122                      8
# 377449               244.0                   167                     28
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 1                    5         0                  85.0
# 2                   17         1                  23.0
# 16                   1         0                   6.0
# 27                   5         0                   6.0
# 52                  11         0                  11.0
# ...                ...       ...                   ...
# 377288               1         1                   1.0
# 377315               7         2                  18.0
# 377337               1         0                   1.0
# 377432               8         4                   8.0
# 377449              28         1                  44.0
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 1                            NaN                    0.0
# 2                           29.0                    4.0
# 16                           NaN                    0.0
# 27                           NaN                   13.0
# 52                          30.0                   11.0
# ...                          ...                    ...
# 377288                      61.0                    7.0
# 377315                       NaN                    8.0
# 377337                      47.0                    1.0
# 377432                       NaN                    8.0
# 377449                      58.0                    1.0
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 1                                  NaN                      0               3
# 2                                 13.0                      1               2
# 16                                 NaN                      1               2
# 27                                 NaN                      1               6
# 52                                27.0                      0               2
# ...                                ...                    ...             ...
# 377288                            61.0                      7               3
# 377315                             NaN                      1               2
# 377337                            38.0                      1               5
# 377432                             NaN                      0               7
# 377449                            58.0                      1               1
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 1                     3            4          4         11              4
# 2                     2            4          5         10              7
# 16                    4            2          2          8              4
# 27                   11            9         19          2             19
# 52                    2            4          5          6              4
# ...                 ...          ...        ...        ...            ...
# 377288                3            5         13         13              6
# 377315                7            2          2         47              8
# 377337                8            6          7         26             14
# 377432                8            8          9          4              9
# 377449                2            1         10          7              2
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 1                 4.0                    3         5               0.0
# 2                 8.0                    2        15               0.0
# 16                7.0                    4        10               0.0
# 27               32.0                   11        20               0.0
# 52                7.0                    2         7               0.0
# ...               ...                  ...       ...               ...
# 377288           15.0                    3        10               0.0
# 377315           10.0                    7        16               0.0
# 377337           19.0                    8        21               0.0
# 377432           11.0                    8        10               0.0
# 377449           18.0                    2         4               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 1                  0                   0                   1           100.0
# 2                  0                   0                   0            73.7
# 16                 0                   0                   3            87.5
# 27                 0                   0                   2            94.3
# 52                 0                   0                   1            84.6
# ...              ...                 ...                 ...             ...
# 377288             0                   0                   3            74.1
# 377315             0                   0                   2            96.6
# 377337             0                   0                   5            93.2
# 377432             0                   0                   1           100.0
# 377449             0                   0                   0            88.5
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 1                   75.0                     0          0           370357
# 2                   25.0                     0          2           704224
# 16                   0.0                     0          0            53161
# 27                  44.4                     0          0            84200
# 52                   0.0                     0          0            50240
# ...                  ...                   ...        ...              ...
# 377288              75.0                     1          0           137656
# 377315              50.0                     0          0           300207
# 377337              16.7                     0          0           111391
# 377432              37.5                     1          0            56621
# 377449               0.0                     0          0            54367
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 1                  372407           23300                      347057
# 2                  112166            5100                      124120
# 16                  38865            5600                       42061
# 27                  34856           33100                       10000
# 52                  32365           21000                       29240
# ...                   ...             ...                         ...
# 377288              36378            4600                       44259
# 377315             308364            8800                      271207
# 377337              95666           21200                       86119
# 377432              30892           28000                       22621
# 377449              18622            2000                       48867
#
#         revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 1                   NaN                     NaN                      NaN
# 2                   NaN                     NaN                      NaN
# 16                  NaN                     NaN                      NaN
# 27                  NaN                     NaN                      NaN
# 52                  NaN                     NaN                      NaN
# ...                 ...                     ...                      ...
# 377288              NaN                     NaN                      NaN
# 377315              NaN                     NaN                      NaN
# 377337              NaN                     NaN                      NaN
# 377432              NaN                     NaN                      NaN
# 377449              NaN                     NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 1                            NaN                     NaN               NaN
# 2                            NaN                     NaN               NaN
# 16                           NaN                     NaN               NaN
# 27                           NaN                     NaN               NaN
# 52                           NaN                     NaN               NaN
# ...                          ...                     ...               ...
# 377288                       NaN                     NaN               NaN
# 377315                       NaN                     NaN               NaN
# 377337                       NaN                     NaN               NaN
# 377432                       NaN                     NaN               NaN
# 377449                       NaN                     NaN               NaN
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_il_6m  \
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 16                   NaN                 NaN                 NaN
# 27                   NaN                 NaN                 NaN
# 52                   NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 377288               NaN                 NaN                 NaN
# 377315               NaN                 NaN                 NaN
# 377337               NaN                 NaN                 NaN
# 377432               NaN                 NaN                 NaN
# 377449               NaN                 NaN                 NaN
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 16                        NaN                               NaN
# 27                        NaN                               NaN
# 52                        NaN                               NaN
# ...                       ...                               ...
# 377288                    NaN                               NaN
# 377315                    NaN                               NaN
# 377337                    NaN                               NaN
# 377432                    NaN                               NaN
# 377449                    NaN                               NaN
#
#         sec_app_collections_12_mths_ex_med  \
# 1                                      NaN
# 2                                      NaN
# 16                                     NaN
# 27                                     NaN
# 52                                     NaN
# ...                                    ...
# 377288                                 NaN
# 377315                                 NaN
# 377337                                 NaN
# 377432                                 NaN
# 377449                                 NaN
#
#         sec_app_mths_since_last_major_derog
# 1                                       NaN
# 2                                       NaN
# 16                                      NaN
# 27                                      NaN
# 52                                      NaN
# ...                                     ...
# 377288                                  NaN
# 377315                                  NaN
# 377337                                  NaN
# 377432                                  NaN
# 377449                                  NaN
#
# [17777 rows x 128 columns]

# %%
df["loan_status"].value_counts()
# Out:
# Current               263622
# Fully Paid            107268
# Charged Off            37538
# Late (31-120 days)      7899
# In Grace Period         2394
# Late (16-30 days)       1775
# Default                  599
# Name: loan_status, dtype: int64

# %%
df[(df["sub_grade"] == "C4") & (df["int_rate"] == "  6.00%")]
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 15963   67278193        NaN      25000        25000          25000.0
# 150841  59572219        NaN      28000        28000          28000.0
# 207494  55717658        NaN      15000        15000          14975.0
# 239220  53434168        NaN      12000        12000          11975.0
# 412419  38596203        NaN       8000         8000           8000.0
#
#               term int_rate  installment grade sub_grade  \
# 15963    60 months    6.00%        52.22     C        C4
# 150841   60 months    6.00%       541.23     C        C4
# 207494   36 months    6.00%       376.25     C        C4
# 239220   60 months    6.00%       241.80     C        C4
# 412419   36 months    6.00%       247.63     C        C4
#
#                            emp_title emp_length home_ownership  annual_inc  \
# 15963   Business Development Manager     1 year       MORTGAGE    125000.0
# 150841            Weather Forecaster  10+ years           RENT     81000.0
# 207494                           DSP    4 years           RENT     60000.0
# 239220       Assistant Store Manager    5 years       MORTGAGE     50000.0
# 412419                        driver    9 years       MORTGAGE     35000.0
#
#        verification_status   issue_d loan_status pymnt_plan  \
# 15963      Source Verified  Dec-2015     Current          n
# 150841        Not Verified  Sep-2015     Current          n
# 207494        Not Verified  Jul-2015     Current          n
# 239220        Not Verified  Jun-2015     Current          n
# 412419        Not Verified  Jan-2015     Current          n
#
#                                                       url desc  \
# 15963   https://lendingclub.com/browse/loanDetail.acti...  NaN
# 150841  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 207494  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 239220  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 412419  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                    purpose                    title zip_code addr_state  \
# 15963   debt_consolidation       Debt consolidation    325xx         FL
# 150841         credit_card  Credit card refinancing    198xx         DE
# 207494  debt_consolidation       Debt consolidation    207xx         MD
# 239220         credit_card  Credit card refinancing    458xx         OH
# 412419  debt_consolidation       Debt consolidation    953xx         CA
#
#           dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 15963   12.59            2         Jun-2005             660              664
# 150841  25.95            0         Jan-1994             670              674
# 207494   8.30            0         Jan-2011             675              679
# 239220  16.35            0         Jun-2008             660              664
# 412419   6.18            1         Apr-1978             675              679
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 15963                2                     8.0                     NaN
# 150841               1                     NaN                     NaN
# 207494               0                     NaN                     NaN
# 239220               0                     NaN                     NaN
# 412419               0                    17.0                     NaN
#
#         open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 15963         11        0      14021        48%         32
# 150841        15        0      38772      84.5%         41
# 207494        25        0      12864      39.8%         26
# 239220         7        0       9809      83.8%          7
# 412419         9        0      10065      63.7%         21
#
#        initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 15963                    w    2057.84        2057.84     26397.26
# 150841                   w   20018.54       20018.54     12046.45
# 207494                   f    4748.65        4740.74     11937.18
# 239220                   f    8548.29        8530.48      5757.96
# 412419                   f    1465.73        1465.73      8200.65
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 15963          26397.26         22942.16        3455.10                 0.0
# 150841         12046.45          7981.46        4064.99                 0.0
# 207494         11917.28         10251.35        1685.83                 0.0
# 239220          5745.96          3451.71        2306.25                 0.0
# 412419          8200.65          6534.27        1666.38                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 15963          0.0                      0.0     Apr-2017            52.22
# 150841         0.0                      0.0     Apr-2017           541.23
# 207494         0.0                      0.0     Apr-2017           400.00
# 239220         0.0                      0.0     Apr-2017           241.80
# 412419         0.0                      0.0     Apr-2017          1147.63
#
#        next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 15963      May-2017           Apr-2017                   644
# 150841     May-2017           Apr-2017                   679
# 207494     May-2017           Apr-2017                   654
# 239220     May-2017           Apr-2017                   664
# 412419     May-2017           Apr-2017                   654
#
#         last_fico_range_low  collections_12_mths_ex_med  \
# 15963                   640                           1
# 150841                  675                           0
# 207494                  650                           0
# 239220                  660                           0
# 412419                  650                           0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 15963                           8.0            1       INDIVIDUAL
# 150841                          NaN            1       INDIVIDUAL
# 207494                          NaN            1       INDIVIDUAL
# 239220                          NaN            1       INDIVIDUAL
# 412419                         17.0            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 15963                NaN        NaN                       NaN               0
# 150841               NaN        NaN                       NaN               0
# 207494               NaN        NaN                       NaN               0
# 239220               NaN        NaN                       NaN               0
# 412419               NaN        NaN                       NaN               0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 15963              0       211002          2.0         3.0          0.0
# 150841             0        66968          NaN         NaN          NaN
# 207494             0        44706          NaN         NaN          NaN
# 239220             0       117153          NaN         NaN          NaN
# 412419             0       143923          NaN         NaN          NaN
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 15963           1.0                16.0        6329.0     29.0          1.0
# 150841          NaN                 NaN           NaN      NaN          NaN
# 207494          NaN                 NaN           NaN      NaN          NaN
# 239220          NaN                 NaN           NaN      NaN          NaN
# 412419          NaN                 NaN           NaN      NaN          NaN
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 15963           1.0     13594.0      47.0             29200     2.0
# 150841          NaN         NaN       NaN             45900     NaN
# 207494          NaN         NaN       NaN             32300     NaN
# 239220          NaN         NaN       NaN             11700     NaN
# 412419          NaN         NaN       NaN             15800     NaN
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 15963           4.0           6.0                     4        19182
# 150841          NaN           NaN                     5         5581
# 207494          NaN           NaN                    11         1863
# 239220          NaN           NaN                     3        16736
# 412419          NaN           NaN                     3        15991
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 15963           7606.0     64.1                         0            0
# 150841          2517.0     79.4                         0            0
# 207494         10226.0     47.8                         0            0
# 239220           773.0     76.6                         0            0
# 412419           692.0     84.6                         0            0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 15963                111.0                   126                      1
# 150841               125.0                   259                     15
# 207494                46.0                    54                      3
# 239220                15.0                    84                     16
# 412419               124.0                   112                      4
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 15963                1         3                  26.0
# 150841              14         1                  24.0
# 207494               3         0                   3.0
# 239220              15         1                  49.0
# 412419               4         4                   6.0
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 15963                       16.0                    0.0
# 150841                       NaN                    6.0
# 207494                       NaN                   10.0
# 239220                       NaN                   15.0
# 412419                       NaN                   12.0
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 15963                             16.0                      1               1
# 150841                             NaN                      0               3
# 207494                             NaN                      0               8
# 239220                             NaN                      0               2
# 412419                             NaN                      1               3
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 15963                 2            3          5         13              6
# 150841                9            4         13         11             14
# 207494               11           12         12          6             19
# 239220                5            2          2          1              5
# 412419                5            3          6          2              7
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 15963            15.0                    2        11               0.0
# 150841           29.0                    9        15               0.0
# 207494           20.0                   11        25               0.0
# 239220            5.0                    5         7               0.0
# 412419           14.0                    5         9               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 15963              0                   1                   2            93.7
# 150841             0                   0                   0           100.0
# 207494             0                   0                   4           100.0
# 239220             0                   0                   0            85.7
# 412419             0                   1                   2            95.2
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 15963               33.3                     0          0           244893
# 150841              66.7                     0          0            79737
# 207494              27.3                     0          0            64142
# 239220              50.0                     0          0           127805
# 412419              66.7                     0          0           318959
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 15963               26915           21200                       22155
# 150841              66968           12200                       33837
# 207494              44706           19600                       31842
# 239220              32690            3300                       26724
# 412419              10941            4500                           0
#
#         revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 15963               NaN                     NaN                      NaN
# 150841              NaN                     NaN                      NaN
# 207494              NaN                     NaN                      NaN
# 239220              NaN                     NaN                      NaN
# 412419              NaN                     NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 15963                        NaN                     NaN               NaN
# 150841                       NaN                     NaN               NaN
# 207494                       NaN                     NaN               NaN
# 239220                       NaN                     NaN               NaN
# 412419                       NaN                     NaN               NaN
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_il_6m  \
# 15963                NaN                 NaN                 NaN
# 150841               NaN                 NaN                 NaN
# 207494               NaN                 NaN                 NaN
# 239220               NaN                 NaN                 NaN
# 412419               NaN                 NaN                 NaN
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 15963                     NaN                               NaN
# 150841                    NaN                               NaN
# 207494                    NaN                               NaN
# 239220                    NaN                               NaN
# 412419                    NaN                               NaN
#
#         sec_app_collections_12_mths_ex_med  \
# 15963                                  NaN
# 150841                                 NaN
# 207494                                 NaN
# 239220                                 NaN
# 412419                                 NaN
#
#         sec_app_mths_since_last_major_derog
# 15963                                   NaN
# 150841                                  NaN
# 207494                                  NaN
# 239220                                  NaN
# 412419                                  NaN

# %%
df2.head(50)
# Out:
#                    LoanStatNew  \
# 0               acc_now_delinq
# 1         acc_open_past_24mths
# 2                   addr_state
# 3                     all_util
# 4                   annual_inc
# 5             annual_inc_joint
# 6             application_type
# 7                  avg_cur_bal
# 8               bc_open_to_buy
# 9                      bc_util
# 10    chargeoff_within_12_mths
# 11     collection_recovery_fee
# 12  collections_12_mths_ex_med
# 13                 delinq_2yrs
# 14                 delinq_amnt
# 15                        desc
# 16                         dti
# 17                   dti_joint
# 18            earliest_cr_line
# 19                  emp_length
# 20                   emp_title
# 21             fico_range_high
# 22              fico_range_low
# 23                 funded_amnt
# 24             funded_amnt_inv
# 25                       grade
# 26              home_ownership
# 27                          id
# 28                     il_util
# 29         initial_list_status
# 30                      inq_fi
# 31                inq_last_12m
# 32              inq_last_6mths
# 33                 installment
# 34                    int_rate
# 35                     issue_d
# 36          last_credit_pull_d
# 37        last_fico_range_high
# 38         last_fico_range_low
# 39             last_pymnt_amnt
# 40                last_pymnt_d
# 41                   loan_amnt
# 42                 loan_status
# 43                  max_bal_bc
# 44                   member_id
# 45          mo_sin_old_il_acct
# 46        mo_sin_old_rev_tl_op
# 47       mo_sin_rcnt_rev_tl_op
# 48              mo_sin_rcnt_tl
# 49                    mort_acc
#
#                                           Description
# 0   The number of accounts on which the borrower i...
# 1          Number of trades opened in past 24 months.
# 2   The state provided by the borrower in the loan...
# 3               Balance to credit limit on all trades
# 4   The self-reported annual income provided by th...
# 5   The combined self-reported annual income provi...
# 6   Indicates whether the loan is an individual ap...
# 7             Average current balance of all accounts
# 8           Total open to buy on revolving bankcards.
# 9   Ratio of total current balance to high credit/...
# 10             Number of charge-offs within 12 months
# 11                     post charge off collection fee
# 12  Number of collections in 12 months excluding m...
# 13  The number of 30+ days past-due incidences of ...
# 14  The past-due amount owed for the accounts on w...
# 15          Loan description provided by the borrower
# 16  A ratio calculated using the borrower’s total ...
# 17  A ratio calculated using the co-borrowers' tot...
# 18  The month the borrower's earliest reported cre...
# 19  Employment length in years. Possible values ar...
# 20  The job title supplied by the Borrower when ap...
# 21  The upper boundary range the borrower’s FICO a...
# 22  The lower boundary range the borrower’s FICO a...
# 23  The total amount committed to that loan at tha...
# 24  The total amount committed by investors for th...
# 25                             LC assigned loan grade
# 26  The home ownership status provided by the borr...
# 27      A unique LC assigned ID for the loan listing.
# 28  Ratio of total current balance to high credit/...
# 29  The initial listing status of the loan. Possib...
# 30               Number of personal finance inquiries
# 31       Number of credit inquiries in past 12 months
# 32  The number of inquiries in past 6 months (excl...
# 33  The monthly payment owed by the borrower if th...
# 34                          Interest Rate on the loan
# 35                The month which the loan was funded
# 36  The most recent month LC pulled credit for thi...
# 37  The upper boundary range the borrower’s last F...
# 38  The lower boundary range the borrower’s last F...
# 39                 Last total payment amount received
# 40                    Last month payment was received
# 41  The listed amount of the loan applied for by t...
# 42                         Current status of the loan
# 43  Maximum current balance owed on all revolving ...
# 44   A unique LC assigned Id for the borrower member.
# 45  Months since oldest bank installment account o...
# 46       Months since oldest revolving account opened
# 47  Months since most recent revolving account opened
# 48            Months since most recent account opened
# 49                       Number of mortgage accounts.

# %%
#Question
#1) Why some guys who have a loan of 36 months and started in 2015 are still current (ex: id 68585839)
#2) Why dti is different than debt/income (ex: id 67278193)

# %% [markdown]
# # Preprocessing

# %%
def interest_as_int(df):
    
    df = df.copy()
    
    df["int_rate"] = df["int_rate"].str.replace("%", "")
    df["int_rate"] = df["int_rate"].astype("float")
    
    return df

df = interest_as_int(df)

# %%
def remove_lines_with_all_nan(df):
    
    df = df.dropna(thresh = 20, axis = 0)
    return df

remove_lines_with_all_nan(df).shape[0]
# Out:
# 188181

# %%
df["fico_mean"] = (df["fico_range_low"] + df["fico_range_high"])/2

# %%
def drop_na(df, thresh = 400000):
    
    df = df.dropna(thresh= thresh, axis = 1)
    
    for i in df.columns:
    
        df = df.dropna(subset = [i])
    
    return df

df_no_na = drop_na(df)

# %%
def remove_variables_no_need(df):
    
    df = df.set_index("id")
    
    df.drop(["funded_amnt", 
             "funded_amnt_inv", 
             "int_rate", 
             "installment", 
             "annual_inc", 
             "issue_d", 
             "loan_status", 
             "pymnt_plan", 
             "url", 
             "zip_code", 
             "addr_state", 
             "earliest_cr_line", 
             "fico_range_low", 
             "fico_range_high", "last_pymnt_d"])

# %%
df_no_na
# Out:
#               id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0       66624733      18000        18000          18000.0   60 months
# 1       68367011      21000        21000          21000.0   60 months
# 2       68615044      16000        16000          16000.0   60 months
# 3       68476697      15700        15700          15700.0   60 months
# 4       68516838      23850        23850          23850.0   60 months
# ...          ...        ...          ...              ...         ...
# 421089  36221446      11575        11575          11575.0   36 months
# 421090  36371250      10000        10000          10000.0   36 months
# 421092  36490806      12000        12000          12000.0   60 months
# 421093  36271333      13000        13000          13000.0   60 months
# 421094  36271262      20000        20000          20000.0   36 months
#
#         int_rate  installment grade sub_grade home_ownership  annual_inc  \
# 0          19.48       471.70     E        E2           RENT    150000.0
# 1          13.99       488.53     C        C4           RENT     52000.0
# 2          13.99       372.21     C        C4       MORTGAGE    142000.0
# 3          16.59       386.74     D        D2       MORTGAGE     48000.0
# 4          17.27       596.21     D        D3            OWN     68046.0
# ...          ...          ...   ...       ...            ...         ...
# 421089     15.59       404.61     D        D1           RENT     25400.0
# 421090     11.99       332.10     B        B5           RENT     31000.0
# 421092     19.99       317.86     E        E3           RENT     64400.0
# 421093     15.99       316.07     D        D2           RENT     35000.0
# 421094     11.99       664.20     B        B5           RENT    100000.0
#
#        verification_status   issue_d  loan_status pymnt_plan  \
# 0             Not Verified  Dec-2015      Current          n
# 1          Source Verified  Dec-2015      Current          n
# 2                 Verified  Dec-2015      Current          n
# 3             Not Verified  Dec-2015      Current          n
# 4             Not Verified  Dec-2015      Current          n
# ...                    ...       ...          ...        ...
# 421089            Verified  Jan-2015   Fully Paid          n
# 421090            Verified  Jan-2015      Current          n
# 421092     Source Verified  Jan-2015  Charged Off          n
# 421093            Verified  Jan-2015  Charged Off          n
# 421094            Verified  Jan-2015      Current          n
#
#                                                       url             purpose  \
# 0       https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 1       https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2       https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 3       https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 4       https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# ...                                                   ...                 ...
# 421089  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 421090  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 421092  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 421093  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 421094  https://lendingclub.com/browse/loanDetail.acti...         credit_card
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 0            Debt consolidation    916xx         CA   9.39            0
# 1       Credit card refinancing    441xx         OH  14.47            0
# 2            Debt consolidation    945xx         CA  17.74            2
# 3       Credit card refinancing    707xx         LA  29.13            0
# 4            Debt consolidation    231xx         VA  24.71            1
# ...                         ...      ...        ...    ...          ...
# 421089  Credit card refinancing    791xx         TX  27.08            0
# 421090       Debt consolidation    905xx         CA  28.69            0
# 421092       Debt consolidation    010xx         MA  27.19            1
# 421093       Debt consolidation    378xx         TN  30.90            0
# 421094  Credit card refinancing    331xx         FL  10.83            0
#
#        earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# 0              Jun-2005             665              669               1
# 1              Jan-2005             680              684               1
# 2              Oct-2004             680              684               2
# 3              Nov-2005             685              689               0
# 4              Sep-1993             665              669               0
# ...                 ...             ...              ...             ...
# 421089         Jul-1999             680              684               0
# 421090         Sep-2004             670              674               0
# 421092         Oct-2003             695              699               2
# 421093         Sep-2003             680              684               0
# 421094         Dec-2001             675              679               1
#
#         open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0             18        1      14052      40.7%         27
# 1              5        0      20374      87.4%         15
# 2             15        2       2273      39.9%         19
# 3             19        0      15458      64.9%         28
# 4             12        0      28220      91.3%         33
# ...          ...      ...        ...        ...        ...
# 421089         9        0      18266        65%         18
# 421090         9        1      14037      82.1%         15
# 421092        17        0       8254      30.6%         20
# 421093         9        1      11031      61.3%         22
# 421094         8        1      33266      79.8%         10
#
#        initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 0                        w   14750.39       14750.39      7362.14
# 1                        w   17030.49       17030.49      7409.56
# 2                        w   12975.66       12975.66      5552.06
# 3                        w   12892.98       12892.98      5764.92
# 4                        f   19648.30       19648.30      8897.38
# ...                    ...        ...            ...          ...
# 421089                   f       0.00           0.00     13976.74
# 421090                   f    2844.71        2844.71      8958.54
# 421092                   w       0.00           0.00      5366.99
# 421093                   w       0.00           0.00      6109.52
# 421094                   f    5689.42        5689.42     17958.65
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0               7362.14          3249.61        4112.53                 0.0
# 1               7409.56          3969.51        3440.05                 0.0
# 2               5552.06          3024.34        2527.72                 0.0
# 3               5764.92          2807.02        2957.90                 0.0
# 4               8897.38          4201.70        4695.68                 0.0
# ...                 ...              ...            ...                 ...
# 421089         13976.74         11575.00        2401.74                 0.0
# 421090          8958.54          7155.29        1803.25                 0.0
# 421092          5366.99          1552.69        2234.98                 0.0
# 421093          6109.52          2527.70        2506.32                 0.0
# 421094         17958.65         14310.58        3648.07                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0             0.00                   0.0000     Apr-2017           471.70
# 1             0.00                   0.0000     Apr-2017           488.53
# 2             0.00                   0.0000     Apr-2017           372.21
# 3             0.00                   0.0000     Apr-2017           386.74
# 4             0.00                   0.0000     Apr-2017           596.21
# ...            ...                      ...          ...              ...
# 421089        0.00                   0.0000     Sep-2016          6281.14
# 421090        0.00                   0.0000     Apr-2017           332.10
# 421092     1579.32                 284.2776     Jan-2016           317.86
# 421093     1075.50                 193.5900     May-2016           316.07
# 421094        0.00                   0.0000     Apr-2017           664.20
#
#        last_credit_pull_d  last_fico_range_high  last_fico_range_low  \
# 0                Apr-2017                   654                  650
# 1                Apr-2017                   674                  670
# 2                Apr-2017                   734                  730
# 3                Apr-2017                   714                  710
# 4                Apr-2017                   674                  670
# ...                   ...                   ...                  ...
# 421089           Nov-2016                   694                  690
# 421090           Apr-2017                   704                  700
# 421092           Oct-2016                   499                    0
# 421093           Dec-2016                   569                  565
# 421094           Apr-2017                   699                  695
#
#         collections_12_mths_ex_med  policy_code application_type  \
# 0                                0            1       INDIVIDUAL
# 1                                0            1       INDIVIDUAL
# 2                                0            1       INDIVIDUAL
# 3                                0            1       INDIVIDUAL
# 4                                0            1       INDIVIDUAL
# ...                            ...          ...              ...
# 421089                           0            1       INDIVIDUAL
# 421090                           0            1       INDIVIDUAL
# 421092                           1            1       INDIVIDUAL
# 421093                           0            1       INDIVIDUAL
# 421094                           0            1       INDIVIDUAL
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  \
# 0                    0            60        36247             34500
# 1                    0             0       372407             23300
# 2                    0             0       667373              5700
# 3                    0             0       270017             23800
# 4                    0           342       525195             30900
# ...                ...           ...          ...               ...
# 421089               0             0        19798             28100
# 421090               0             0        25274             17100
# 421092               0             0        58418             27000
# 421093               0             0        34178             18000
# 421094               0             0        33307             41700
#
#         acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0                          7         2014          5128.0     51.3
# 1                          1        74481          2926.0     87.4
# 2                          7        47670          2827.0     44.6
# 3                          5        14211          1516.0     87.7
# 4                          0        47745             6.0     99.9
# ...                      ...          ...             ...      ...
# 421089                     1         2200          9234.0     66.4
# 421090                     2         3159           448.0     95.1
# 421092                     6         3895          3752.0     61.3
# 421093                     7         3798          2554.0     75.9
# 421094                     1         4163          8434.0     79.8
#
#         chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                              0            0               115.0
# 1                              0            0                76.0
# 2                              0            0               134.0
# 3                              0            0               112.0
# 4                              0            0               140.0
# ...                          ...          ...                 ...
# 421089                         0            0               113.0
# 421090                         0            0               122.0
# 421092                         0            0                56.0
# 421093                         0            0               134.0
# 421094                         0            0               146.0
#
#         mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                        112                      1               1         2
# 1                        131                     85               5         0
# 2                         98                     23              17         1
# 3                        121                      4               4         1
# 4                        267                     70              45         4
# ...                      ...                    ...             ...       ...
# 421089                   184                     48               8         0
# 421090                   115                     17              10         0
# 421092                    83                      5               5         0
# 421093                   108                      6               6         0
# 421094                   155                      5               5         0
#
#         mths_since_recent_bc  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                        9.0                      0               6
# 1                       85.0                      0               3
# 2                       23.0                      1               2
# 3                        4.0                      1               3
# 4                       99.0                      2               1
# ...                      ...                    ...             ...
# 421089                  48.0                      0               7
# 421090                  90.0                      0               3
# 421092                  12.0                      1               5
# 421093                  17.0                      0               4
# 421094                   5.0                      0               5
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                    13            7          8          6             16
# 1                     3            4          4         11              4
# 2                     2            4          5         10              7
# 3                     6            4          5         13              9
# 4                     7            2          6          9              9
# ...                 ...          ...        ...        ...            ...
# 421089                7            7         10          5              8
# 421090                6            3          4          7              7
# 421092                7            7          7          3             15
# 421093                6            4          4         12              7
# 421094                5            6          7          1              6
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0                19.0                   13        18               0.0
# 1                 4.0                    3         5               0.0
# 2                 8.0                    2        15               0.0
# 3                14.0                    7        19               0.0
# 4                20.0                    8        12               0.0
# ...               ...                  ...       ...               ...
# 421089           13.0                    7         9               0.0
# 421090            8.0                    6         9               0.0
# 421092           16.0                    7        17               0.0
# 421093           10.0                    6         9               0.0
# 421094            7.0                    5         8               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0                  0                   0                   3           100.0
# 1                  0                   0                   1           100.0
# 2                  0                   0                   0            73.7
# 3                  0                   0                   3            96.4
# 4                  0                   1                   0            90.9
# ...              ...                 ...                 ...             ...
# 421089             0                   0                   1           100.0
# 421090             0                   0                   1           100.0
# 421092             0                   1                   2            95.0
# 421093             0                   0                   3           100.0
# 421094             0                   0                   1           100.0
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                   14.3                     1          0            65819
# 1                   75.0                     0          0           370357
# 2                   25.0                     0          2           704224
# 3                   75.0                     0          0           305962
# 4                  100.0                     0          0           554242
# ...                  ...                   ...        ...              ...
# 421089              42.9                     0          0            29866
# 421090             100.0                     0          0            32950
# 421092              66.7                     0          0            96919
# 421093              50.0                     1          0            51239
# 421094              50.0                     0          1            43740
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                   36247           10300                       31319
# 1                  372407           23300                      347057
# 2                  112166            5100                      124120
# 3                   83774           12300                       81126
# 4                   32673            7500                       10100
# ...                   ...             ...                         ...
# 421089              19798           27500                        1766
# 421090              25274            9200                       15850
# 421092              58418            9700                       69919
# 421093              34178           10600                       33239
# 421094              33307           41700                           0
#
#         fico_mean
# 0           667.0
# 1           682.0
# 2           682.0
# 3           687.0
# 4           667.0
# ...           ...
# 421089      682.0
# 421090      672.0
# 421092      697.0
# 421093      682.0
# 421094      677.0
#
# [385537 rows x 88 columns]

# %%
df_no_na["total_rec_late_fee"].value_counts()
# Out:
# 0.00     377857
# 15.00      1976
# 30.00       325
# 45.00        99
# 60.00        31
#           ...
# 36.29         1
# 50.97         1
# 22.79         1
# 61.33         1
# 32.73         1
# Name: total_rec_late_fee, Length: 2616, dtype: int64

# %% [markdown]
# # EDA

# %%
dti_by_grade = df.groupby("grade")["dti"].mean()
income_by_grade = df.groupby("grade")["annual_inc"].mean()
dti_by_subgrade = df.groupby("sub_grade")["dti"].mean()
income_by_subgrade = df.groupby("sub_grade")["annual_inc"].mean()
interest_rate_by_grade = df.groupby("grade")["int_rate"].mean()
interest_rate_by_subgrade = df.groupby("sub_grade")["int_rate"].mean()

# %%
def build_bar_plot(col_name, bar_height, x_label, y_label, title):
    
    bar_positions = range(bar_height.size) 
    tick_positions = range(bar_height.size) 
    
    if bar_height.size > 10:
        fig, ax = plt.subplots(figsize = (15,6))
    else:
        fig, ax = plt.subplots()
        
    ax.bar(bar_positions, bar_height, 0.5)
    ax.set_xticks(tick_positions)
    ax.set_xticklabels(col_name)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)
    
    plt.show()
    

build_bar_plot(dti_by_grade.index, 
               dti_by_grade, 
               "Borrowers grade", 
               "mean debt to ratio", 
               "mean debt to ratio by borrowers grade")

build_bar_plot(income_by_grade.index, 
               income_by_grade, 
               "Borrowers grade", 
               "Annual income", 
               "Annual income by borrowers grade")

build_bar_plot(dti_by_subgrade.index, 
               dti_by_subgrade, 
               "Borrowers subgrade", 
               "mean debt to ratio", 
               "mean debt to ratio by borrowers subgrade")

build_bar_plot(income_by_subgrade.index, 
               income_by_subgrade, 
               "Borrowers subgrade", 
               "Annual income", 
               "Annual income by borrowers subgrade")

build_bar_plot(interest_rate_by_grade.index, 
               interest_rate_by_grade, 
               "Borrowers grade", 
               "interest rate", 
               "interest rate by borrowers grade")

build_bar_plot(interest_rate_by_subgrade.index, 
               interest_rate_by_subgrade, 
               "Borrowers subgrade", 
               "interest rate", 
               "interest rate by borrowers subgrade")

# %%
#interest rate and income
fig, ax = plt.subplots()
ax.scatter(df["annual_inc"], df["int_rate"], alpha = 1)
ax.set_xlim((10000, 150000))
ax.set_ylim((5, 40))
plt.show()

# %%
l = random.sample(range(df.shape[0]), 500)

# %%
df_scat_sample = df.iloc[l,:]

# %%
df_scat_sample
fig, ax = plt.subplots()
ax.scatter(df_scat_sample["annual_inc"], df_scat_sample["int_rate"], alpha = 1)
#ax.set_xlim((10000, 150000))
#ax.set_ylim((5, 40))
plt.show()

# %%
np.corrcoef(df["dti"], df["int_rate"])
# Out:
# array([[1.        , 0.07792699],
#        [0.07792699, 1.        ]])

# %%
np.corrcoef(df["fico_mean"], df["int_rate"])
# Out:
# array([[ 1.        , -0.37620634],
#        [-0.37620634,  1.        ]])

# %%
df_scat_sample
fig, ax = plt.subplots()
ax.scatter(df_scat_sample["fico_mean"], df_scat_sample["int_rate"], alpha = 1)
#ax.set_xlim((10000, 150000))
#ax.set_ylim((5, 40))
plt.show()

# %%
fig, ax = plt.subplots()
ax.boxplot(df_scat_sample["fico_mean"])
plt.show()

# %%
for subgrade in df["sub_grade"].sort_values().unique():
    print("subgrade ", subgrade, "there are ", df[df["sub_grade"] == subgrade]["int_rate"].nunique(), " different values")
    print("these values are: ", df[df["sub_grade"] == subgrade]["int_rate"].unique())
# Out:
# subgrade  A1 there are  3  different values
# these values are:  [5.32 5.93 6.03]
# subgrade  A2 there are  4  different values
# these values are:  [6.49 6.24 6.   6.39]
# subgrade  A3 there are  3  different values
# these values are:  [6.99 6.89 6.68]
# subgrade  A4 there are  4  different values
# these values are:  [7.49 7.26 6.   6.92]
# subgrade  A5 there are  4  different values
# these values are:  [7.91 7.89 6.   8.19]
# subgrade  B1 there are  5  different values
# these values are:  [8.49 8.38 6.   8.18 8.67]
# subgrade  B2 there are  3  different values
# these values are:  [9.17 6.   9.49]
# subgrade  B3 there are  5  different values
# these values are:  [ 9.8   9.76  6.    9.99 10.49]
# subgrade  B4 there are  5  different values
# these values are:  [10.78 10.64  6.   10.99 11.44]
# subgrade  B5 there are  6  different values
# these values are:  [11.48 11.22  6.   11.49 11.53 11.99]
# subgrade  C1 there are  5  different values
# these values are:  [11.99 12.05  6.   12.29 12.39]
# subgrade  C2 there are  5  different values
# these values are:  [12.88  6.   12.59 12.69 12.99]
# subgrade  C3 there are  5  different values
# these values are:  [13.44 13.18  6.   13.33 13.66]
# subgrade  C4 there are  4  different values
# these values are:  [13.99 13.67  6.   14.31]
# subgrade  C5 there are  6  different values
# these values are:  [14.85 14.48  6.   14.33 14.65 14.99]
# subgrade  D1 there are  4  different values
# these values are:  [15.77 15.41 15.61 15.59]
# subgrade  D2 there are  4  different values
# these values are:  [16.59 16.55  6.   15.99]
# subgrade  D3 there are  5  different values
# these values are:  [17.27 16.99  6.   16.9  16.49]
# subgrade  D4 there are  4  different values
# these values are:  [17.97 17.57  6.   17.14]
# subgrade  D5 there are  3  different values
# these values are:  [18.49 17.86  6.  ]
# subgrade  E1 there are  5  different values
# these values are:  [18.99 18.2  18.25  6.   18.54]
# subgrade  E2 there are  6  different values
# these values are:  [19.48 18.49 18.55  6.   18.84 19.24]
# subgrade  E3 there are  6  different values
# these values are:  [19.89 18.99  6.   19.19 19.52 19.99]
# subgrade  E4 there are  5  different values
# these values are:  [20.5  19.99  6.   20.49 20.99]
# subgrade  E5 there are  5  different values
# these values are:  [21.48 20.99  6.   21.67 21.99]
# subgrade  F1 there are  4  different values
# these values are:  [22.45  6.   21.99 22.99]
# subgrade  F2 there are  4  different values
# these values are:  [23.13 22.99  6.   23.99]
# subgrade  F3 there are  3  different values
# these values are:  [24.24 23.99 24.5 ]
# subgrade  F4 there are  2  different values
# these values are:  [25.09 24.99]
# subgrade  F5 there are  5  different values
# these values are:  [26.06 25.99 25.78 25.57  6.  ]
# subgrade  G1 there are  3  different values
# these values are:  [26.99 26.77 25.8 ]
# subgrade  G2 there are  3  different values
# these values are:  [27.49 27.31 25.83]
# subgrade  G3 there are  3  different values
# these values are:  [27.99 27.88 25.89]
# subgrade  G4 there are  2  different values
# these values are:  [28.49 25.99]
# subgrade  G5 there are  2  different values
# these values are:  [28.99 26.06]

# %%
sns.heatmap(temp.head(1000).isnull(), cbar = False)

# %%
for i in temp.columns:
    
    temp = temp.dropna(subset = [i])

# %%
temp
# Out:
#               id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0       66624733      18000        18000          18000.0   60 months
# 1       68367011      21000        21000          21000.0   60 months
# 2       68615044      16000        16000          16000.0   60 months
# 3       68476697      15700        15700          15700.0   60 months
# 4       68516838      23850        23850          23850.0   60 months
# ...          ...        ...          ...              ...         ...
# 421089  36221446      11575        11575          11575.0   36 months
# 421090  36371250      10000        10000          10000.0   36 months
# 421092  36490806      12000        12000          12000.0   60 months
# 421093  36271333      13000        13000          13000.0   60 months
# 421094  36271262      20000        20000          20000.0   36 months
#
#         int_rate  installment grade sub_grade home_ownership  annual_inc  \
# 0          19.48       471.70     E        E2           RENT    150000.0
# 1          13.99       488.53     C        C4           RENT     52000.0
# 2          13.99       372.21     C        C4       MORTGAGE    142000.0
# 3          16.59       386.74     D        D2       MORTGAGE     48000.0
# 4          17.27       596.21     D        D3            OWN     68046.0
# ...          ...          ...   ...       ...            ...         ...
# 421089     15.59       404.61     D        D1           RENT     25400.0
# 421090     11.99       332.10     B        B5           RENT     31000.0
# 421092     19.99       317.86     E        E3           RENT     64400.0
# 421093     15.99       316.07     D        D2           RENT     35000.0
# 421094     11.99       664.20     B        B5           RENT    100000.0
#
#        verification_status   issue_d  loan_status pymnt_plan  \
# 0             Not Verified  Dec-2015      Current          n
# 1          Source Verified  Dec-2015      Current          n
# 2                 Verified  Dec-2015      Current          n
# 3             Not Verified  Dec-2015      Current          n
# 4             Not Verified  Dec-2015      Current          n
# ...                    ...       ...          ...        ...
# 421089            Verified  Jan-2015   Fully Paid          n
# 421090            Verified  Jan-2015      Current          n
# 421092     Source Verified  Jan-2015  Charged Off          n
# 421093            Verified  Jan-2015  Charged Off          n
# 421094            Verified  Jan-2015      Current          n
#
#                                                       url             purpose  \
# 0       https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 1       https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 2       https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 3       https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 4       https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# ...                                                   ...                 ...
# 421089  https://lendingclub.com/browse/loanDetail.acti...         credit_card
# 421090  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 421092  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 421093  https://lendingclub.com/browse/loanDetail.acti...  debt_consolidation
# 421094  https://lendingclub.com/browse/loanDetail.acti...         credit_card
#
#                           title zip_code addr_state    dti  delinq_2yrs  \
# 0            Debt consolidation    916xx         CA   9.39            0
# 1       Credit card refinancing    441xx         OH  14.47            0
# 2            Debt consolidation    945xx         CA  17.74            2
# 3       Credit card refinancing    707xx         LA  29.13            0
# 4            Debt consolidation    231xx         VA  24.71            1
# ...                         ...      ...        ...    ...          ...
# 421089  Credit card refinancing    791xx         TX  27.08            0
# 421090       Debt consolidation    905xx         CA  28.69            0
# 421092       Debt consolidation    010xx         MA  27.19            1
# 421093       Debt consolidation    378xx         TN  30.90            0
# 421094  Credit card refinancing    331xx         FL  10.83            0
#
#        earliest_cr_line  fico_range_low  fico_range_high  inq_last_6mths  \
# 0              Jun-2005             665              669               1
# 1              Jan-2005             680              684               1
# 2              Oct-2004             680              684               2
# 3              Nov-2005             685              689               0
# 4              Sep-1993             665              669               0
# ...                 ...             ...              ...             ...
# 421089         Jul-1999             680              684               0
# 421090         Sep-2004             670              674               0
# 421092         Oct-2003             695              699               2
# 421093         Sep-2003             680              684               0
# 421094         Dec-2001             675              679               1
#
#         open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0             18        1      14052      40.7%         27
# 1              5        0      20374      87.4%         15
# 2             15        2       2273      39.9%         19
# 3             19        0      15458      64.9%         28
# 4             12        0      28220      91.3%         33
# ...          ...      ...        ...        ...        ...
# 421089         9        0      18266        65%         18
# 421090         9        1      14037      82.1%         15
# 421092        17        0       8254      30.6%         20
# 421093         9        1      11031      61.3%         22
# 421094         8        1      33266      79.8%         10
#
#        initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 0                        w   14750.39       14750.39      7362.14
# 1                        w   17030.49       17030.49      7409.56
# 2                        w   12975.66       12975.66      5552.06
# 3                        w   12892.98       12892.98      5764.92
# 4                        f   19648.30       19648.30      8897.38
# ...                    ...        ...            ...          ...
# 421089                   f       0.00           0.00     13976.74
# 421090                   f    2844.71        2844.71      8958.54
# 421092                   w       0.00           0.00      5366.99
# 421093                   w       0.00           0.00      6109.52
# 421094                   f    5689.42        5689.42     17958.65
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0               7362.14          3249.61        4112.53                 0.0
# 1               7409.56          3969.51        3440.05                 0.0
# 2               5552.06          3024.34        2527.72                 0.0
# 3               5764.92          2807.02        2957.90                 0.0
# 4               8897.38          4201.70        4695.68                 0.0
# ...                 ...              ...            ...                 ...
# 421089         13976.74         11575.00        2401.74                 0.0
# 421090          8958.54          7155.29        1803.25                 0.0
# 421092          5366.99          1552.69        2234.98                 0.0
# 421093          6109.52          2527.70        2506.32                 0.0
# 421094         17958.65         14310.58        3648.07                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0             0.00                   0.0000     Apr-2017           471.70
# 1             0.00                   0.0000     Apr-2017           488.53
# 2             0.00                   0.0000     Apr-2017           372.21
# 3             0.00                   0.0000     Apr-2017           386.74
# 4             0.00                   0.0000     Apr-2017           596.21
# ...            ...                      ...          ...              ...
# 421089        0.00                   0.0000     Sep-2016          6281.14
# 421090        0.00                   0.0000     Apr-2017           332.10
# 421092     1579.32                 284.2776     Jan-2016           317.86
# 421093     1075.50                 193.5900     May-2016           316.07
# 421094        0.00                   0.0000     Apr-2017           664.20
#
#        last_credit_pull_d  last_fico_range_high  last_fico_range_low  \
# 0                Apr-2017                   654                  650
# 1                Apr-2017                   674                  670
# 2                Apr-2017                   734                  730
# 3                Apr-2017                   714                  710
# 4                Apr-2017                   674                  670
# ...                   ...                   ...                  ...
# 421089           Nov-2016                   694                  690
# 421090           Apr-2017                   704                  700
# 421092           Oct-2016                   499                    0
# 421093           Dec-2016                   569                  565
# 421094           Apr-2017                   699                  695
#
#         collections_12_mths_ex_med  policy_code application_type  \
# 0                                0            1       INDIVIDUAL
# 1                                0            1       INDIVIDUAL
# 2                                0            1       INDIVIDUAL
# 3                                0            1       INDIVIDUAL
# 4                                0            1       INDIVIDUAL
# ...                            ...          ...              ...
# 421089                           0            1       INDIVIDUAL
# 421090                           0            1       INDIVIDUAL
# 421092                           1            1       INDIVIDUAL
# 421093                           0            1       INDIVIDUAL
# 421094                           0            1       INDIVIDUAL
#
#         acc_now_delinq  tot_coll_amt  tot_cur_bal  total_rev_hi_lim  \
# 0                    0            60        36247             34500
# 1                    0             0       372407             23300
# 2                    0             0       667373              5700
# 3                    0             0       270017             23800
# 4                    0           342       525195             30900
# ...                ...           ...          ...               ...
# 421089               0             0        19798             28100
# 421090               0             0        25274             17100
# 421092               0             0        58418             27000
# 421093               0             0        34178             18000
# 421094               0             0        33307             41700
#
#         acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0                          7         2014          5128.0     51.3
# 1                          1        74481          2926.0     87.4
# 2                          7        47670          2827.0     44.6
# 3                          5        14211          1516.0     87.7
# 4                          0        47745             6.0     99.9
# ...                      ...          ...             ...      ...
# 421089                     1         2200          9234.0     66.4
# 421090                     2         3159           448.0     95.1
# 421092                     6         3895          3752.0     61.3
# 421093                     7         3798          2554.0     75.9
# 421094                     1         4163          8434.0     79.8
#
#         chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                              0            0               115.0
# 1                              0            0                76.0
# 2                              0            0               134.0
# 3                              0            0               112.0
# 4                              0            0               140.0
# ...                          ...          ...                 ...
# 421089                         0            0               113.0
# 421090                         0            0               122.0
# 421092                         0            0                56.0
# 421093                         0            0               134.0
# 421094                         0            0               146.0
#
#         mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                        112                      1               1         2
# 1                        131                     85               5         0
# 2                         98                     23              17         1
# 3                        121                      4               4         1
# 4                        267                     70              45         4
# ...                      ...                    ...             ...       ...
# 421089                   184                     48               8         0
# 421090                   115                     17              10         0
# 421092                    83                      5               5         0
# 421093                   108                      6               6         0
# 421094                   155                      5               5         0
#
#         mths_since_recent_bc  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                        9.0                      0               6
# 1                       85.0                      0               3
# 2                       23.0                      1               2
# 3                        4.0                      1               3
# 4                       99.0                      2               1
# ...                      ...                    ...             ...
# 421089                  48.0                      0               7
# 421090                  90.0                      0               3
# 421092                  12.0                      1               5
# 421093                  17.0                      0               4
# 421094                   5.0                      0               5
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                    13            7          8          6             16
# 1                     3            4          4         11              4
# 2                     2            4          5         10              7
# 3                     6            4          5         13              9
# 4                     7            2          6          9              9
# ...                 ...          ...        ...        ...            ...
# 421089                7            7         10          5              8
# 421090                6            3          4          7              7
# 421092                7            7          7          3             15
# 421093                6            4          4         12              7
# 421094                5            6          7          1              6
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0                19.0                   13        18               0.0
# 1                 4.0                    3         5               0.0
# 2                 8.0                    2        15               0.0
# 3                14.0                    7        19               0.0
# 4                20.0                    8        12               0.0
# ...               ...                  ...       ...               ...
# 421089           13.0                    7         9               0.0
# 421090            8.0                    6         9               0.0
# 421092           16.0                    7        17               0.0
# 421093           10.0                    6         9               0.0
# 421094            7.0                    5         8               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0                  0                   0                   3           100.0
# 1                  0                   0                   1           100.0
# 2                  0                   0                   0            73.7
# 3                  0                   0                   3            96.4
# 4                  0                   1                   0            90.9
# ...              ...                 ...                 ...             ...
# 421089             0                   0                   1           100.0
# 421090             0                   0                   1           100.0
# 421092             0                   1                   2            95.0
# 421093             0                   0                   3           100.0
# 421094             0                   0                   1           100.0
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                   14.3                     1          0            65819
# 1                   75.0                     0          0           370357
# 2                   25.0                     0          2           704224
# 3                   75.0                     0          0           305962
# 4                  100.0                     0          0           554242
# ...                  ...                   ...        ...              ...
# 421089              42.9                     0          0            29866
# 421090             100.0                     0          0            32950
# 421092              66.7                     0          0            96919
# 421093              50.0                     1          0            51239
# 421094              50.0                     0          1            43740
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                   36247           10300                       31319
# 1                  372407           23300                      347057
# 2                  112166            5100                      124120
# 3                   83774           12300                       81126
# 4                   32673            7500                       10100
# ...                   ...             ...                         ...
# 421089              19798           27500                        1766
# 421090              25274            9200                       15850
# 421092              58418            9700                       69919
# 421093              34178           10600                       33239
# 421094              33307           41700                           0
#
#         fico_mean
# 0           667.0
# 1           682.0
# 2           682.0
# 3           687.0
# 4           667.0
# ...           ...
# 421089      682.0
# 421090      672.0
# 421092      697.0
# 421093      682.0
# 421094      677.0
#
# [385537 rows x 88 columns]

# %%
len(temp.columns)
# Out:
# 88

# %%
temp["mths_since_last_record"].isnull().sum()
# Out:
# 346680

# %%
len(df.columns)
# Out:
# 129

# %%
df
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 0       66624733        NaN      18000        18000          18000.0
# 1       68367011        NaN      21000        21000          21000.0
# 2       68615044        NaN      16000        16000          16000.0
# 3       68476697        NaN      15700        15700          15700.0
# 4       68516838        NaN      23850        23850          23850.0
# ...          ...        ...        ...          ...              ...
# 421090  36371250        NaN      10000        10000          10000.0
# 421091  36441262        NaN      24000        24000          24000.0
# 421092  36490806        NaN      12000        12000          12000.0
# 421093  36271333        NaN      13000        13000          13000.0
# 421094  36271262        NaN      20000        20000          20000.0
#
#               term  int_rate  installment grade sub_grade  \
# 0        60 months     19.48       471.70     E        E2
# 1        60 months     13.99       488.53     C        C4
# 2        60 months     13.99       372.21     C        C4
# 3        60 months     16.59       386.74     D        D2
# 4        60 months     17.27       596.21     D        D3
# ...            ...       ...          ...   ...       ...
# 421090   36 months     11.99       332.10     B        B5
# 421091   36 months     11.99       797.03     B        B5
# 421092   60 months     19.99       317.86     E        E3
# 421093   60 months     15.99       316.07     D        D2
# 421094   36 months     11.99       664.20     B        B5
#
#                               emp_title emp_length home_ownership  annual_inc  \
# 0                      Software Manager    7 years           RENT    150000.0
# 1                    Resident physician   < 1 year           RENT     52000.0
# 2                      Registered Nurse    9 years       MORTGAGE    142000.0
# 3                               Teacher    6 years       MORTGAGE     48000.0
# 4                               Teacher  10+ years            OWN     68046.0
# ...                                 ...        ...            ...         ...
# 421090                 Office Assistant    8 years           RENT     31000.0
# 421091          Director of Maintenance  10+ years       MORTGAGE     79000.0
# 421092                          Painter     1 year           RENT     64400.0
# 421093         Radiologist Technologist    5 years           RENT     35000.0
# 421094  Manager Hotel Operations Oasis   10+ years           RENT    100000.0
#
#        verification_status   issue_d  loan_status pymnt_plan  \
# 0             Not Verified  Dec-2015      Current          n
# 1          Source Verified  Dec-2015      Current          n
# 2                 Verified  Dec-2015      Current          n
# 3             Not Verified  Dec-2015      Current          n
# 4             Not Verified  Dec-2015      Current          n
# ...                    ...       ...          ...        ...
# 421090            Verified  Jan-2015      Current          n
# 421091            Verified  Jan-2015      Current          n
# 421092     Source Verified  Jan-2015  Charged Off          n
# 421093            Verified  Jan-2015  Charged Off          n
# 421094            Verified  Jan-2015      Current          n
#
#                                                       url desc  \
# 0       https://lendingclub.com/browse/loanDetail.acti...  NaN
# 1       https://lendingclub.com/browse/loanDetail.acti...  NaN
# 2       https://lendingclub.com/browse/loanDetail.acti...  NaN
# 3       https://lendingclub.com/browse/loanDetail.acti...  NaN
# 4       https://lendingclub.com/browse/loanDetail.acti...  NaN
# ...                                                   ...  ...
# 421090  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421091  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421092  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421093  https://lendingclub.com/browse/loanDetail.acti...  NaN
# 421094  https://lendingclub.com/browse/loanDetail.acti...  NaN
#
#                    purpose                    title zip_code addr_state  \
# 0       debt_consolidation       Debt consolidation    916xx         CA
# 1              credit_card  Credit card refinancing    441xx         OH
# 2       debt_consolidation       Debt consolidation    945xx         CA
# 3              credit_card  Credit card refinancing    707xx         LA
# 4       debt_consolidation       Debt consolidation    231xx         VA
# ...                    ...                      ...      ...        ...
# 421090  debt_consolidation       Debt consolidation    905xx         CA
# 421091    home_improvement         Home improvement    072xx         NJ
# 421092  debt_consolidation       Debt consolidation    010xx         MA
# 421093  debt_consolidation       Debt consolidation    378xx         TN
# 421094         credit_card  Credit card refinancing    331xx         FL
#
#           dti  delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0        9.39            0         Jun-2005             665              669
# 1       14.47            0         Jan-2005             680              684
# 2       17.74            2         Oct-2004             680              684
# 3       29.13            0         Nov-2005             685              689
# 4       24.71            1         Sep-1993             665              669
# ...       ...          ...              ...             ...              ...
# 421090  28.69            0         Sep-2004             670              674
# 421091   3.90            0         Mar-1974             660              664
# 421092  27.19            1         Oct-2003             695              699
# 421093  30.90            0         Sep-2003             680              684
# 421094  10.83            0         Dec-2001             675              679
#
#         inq_last_6mths  mths_since_last_delinq  mths_since_last_record  \
# 0                    1                     NaN                    75.0
# 1                    1                     NaN                     NaN
# 2                    2                     8.0                    39.0
# 3                    0                    66.0                     NaN
# 4                    0                    23.0                     NaN
# ...                ...                     ...                     ...
# 421090               0                     NaN                    77.0
# 421091               1                    26.0                     NaN
# 421092               2                    22.0                     NaN
# 421093               0                     NaN                    84.0
# 421094               1                     NaN                   110.0
#
#         open_acc  pub_rec  revol_bal revol_util  total_acc  \
# 0             18        1      14052      40.7%         27
# 1              5        0      20374      87.4%         15
# 2             15        2       2273      39.9%         19
# 3             19        0      15458      64.9%         28
# 4             12        0      28220      91.3%         33
# ...          ...      ...        ...        ...        ...
# 421090         9        1      14037      82.1%         15
# 421091         5        0       8621      84.5%         23
# 421092        17        0       8254      30.6%         20
# 421093         9        1      11031      61.3%         22
# 421094         8        1      33266      79.8%         10
#
#        initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 0                        w   14750.39       14750.39      7362.14
# 1                        w   17030.49       17030.49      7409.56
# 2                        w   12975.66       12975.66      5552.06
# 3                        w   12892.98       12892.98      5764.92
# 4                        f   19648.30       19648.30      8897.38
# ...                    ...        ...            ...          ...
# 421090                   f    2844.71        2844.71      8958.54
# 421091                   f    6827.60        6827.60     21487.84
# 421092                   w       0.00           0.00      5366.99
# 421093                   w       0.00           0.00      6109.52
# 421094                   f    5689.42        5689.42     17958.65
#
#         total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0               7362.14          3249.61        4112.53                 0.0
# 1               7409.56          3969.51        3440.05                 0.0
# 2               5552.06          3024.34        2527.72                 0.0
# 3               5764.92          2807.02        2957.90                 0.0
# 4               8897.38          4201.70        4695.68                 0.0
# ...                 ...              ...            ...                 ...
# 421090          8958.54          7155.29        1803.25                 0.0
# 421091         21487.84         17172.40        4315.44                 0.0
# 421092          5366.99          1552.69        2234.98                 0.0
# 421093          6109.52          2527.70        2506.32                 0.0
# 421094         17958.65         14310.58        3648.07                 0.0
#
#         recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0             0.00                   0.0000     Apr-2017           471.70
# 1             0.00                   0.0000     Apr-2017           488.53
# 2             0.00                   0.0000     Apr-2017           372.21
# 3             0.00                   0.0000     Apr-2017           386.74
# 4             0.00                   0.0000     Apr-2017           596.21
# ...            ...                      ...          ...              ...
# 421090        0.00                   0.0000     Apr-2017           332.10
# 421091        0.00                   0.0000     Apr-2017           797.03
# 421092     1579.32                 284.2776     Jan-2016           317.86
# 421093     1075.50                 193.5900     May-2016           316.07
# 421094        0.00                   0.0000     Apr-2017           664.20
#
#        next_pymnt_d last_credit_pull_d  last_fico_range_high  \
# 0          May-2017           Apr-2017                   654
# 1          May-2017           Apr-2017                   674
# 2          Apr-2017           Apr-2017                   734
# 3          Apr-2017           Apr-2017                   714
# 4          May-2017           Apr-2017                   674
# ...             ...                ...                   ...
# 421090     May-2017           Apr-2017                   704
# 421091     May-2017           Apr-2017                   704
# 421092          NaN           Oct-2016                   499
# 421093          NaN           Dec-2016                   569
# 421094     May-2017           Apr-2017                   699
#
#         last_fico_range_low  collections_12_mths_ex_med  \
# 0                       650                           0
# 1                       670                           0
# 2                       730                           0
# 3                       710                           0
# 4                       670                           0
# ...                     ...                         ...
# 421090                  700                           0
# 421091                  700                           0
# 421092                    0                           1
# 421093                  565                           0
# 421094                  695                           0
#
#         mths_since_last_major_derog  policy_code application_type  \
# 0                               NaN            1       INDIVIDUAL
# 1                               NaN            1       INDIVIDUAL
# 2                              43.0            1       INDIVIDUAL
# 3                              72.0            1       INDIVIDUAL
# 4                              23.0            1       INDIVIDUAL
# ...                             ...          ...              ...
# 421090                          NaN            1       INDIVIDUAL
# 421091                         29.0            1       INDIVIDUAL
# 421092                         22.0            1       INDIVIDUAL
# 421093                          NaN            1       INDIVIDUAL
# 421094                          NaN            1       INDIVIDUAL
#
#         annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0                    NaN        NaN                       NaN               0
# 1                    NaN        NaN                       NaN               0
# 2                    NaN        NaN                       NaN               0
# 3                    NaN        NaN                       NaN               0
# 4                    NaN        NaN                       NaN               0
# ...                  ...        ...                       ...             ...
# 421090               NaN        NaN                       NaN               0
# 421091               NaN        NaN                       NaN               0
# 421092               NaN        NaN                       NaN               0
# 421093               NaN        NaN                       NaN               0
# 421094               NaN        NaN                       NaN               0
#
#         tot_coll_amt  tot_cur_bal  open_acc_6m  open_il_6m  open_il_12m  \
# 0                 60        36247          2.0         2.0          1.0
# 1                  0       372407          1.0         1.0          1.0
# 2                  0       667373          0.0         7.0          0.0
# 3                  0       270017          2.0         9.0          1.0
# 4                342       525195          0.0         1.0          0.0
# ...              ...          ...          ...         ...          ...
# 421090             0        25274          NaN         NaN          NaN
# 421091             0       140285          NaN         NaN          NaN
# 421092             0        58418          NaN         NaN          NaN
# 421093             0        34178          NaN         NaN          NaN
# 421094             0        33307          NaN         NaN          NaN
#
#         open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0               3.0                 2.0       22195.0     71.0          2.0
# 1               1.0                 5.0      352033.0      NaN          0.0
# 2               6.0                17.0      109893.0     69.0          0.0
# 3               3.0                 6.0       68316.0    101.0          2.0
# 4               0.0                45.0        4453.0     44.0          0.0
# ...             ...                 ...           ...      ...          ...
# 421090          NaN                 NaN           NaN      NaN          NaN
# 421091          NaN                 NaN           NaN      NaN          NaN
# 421092          NaN                 NaN           NaN      NaN          NaN
# 421093          NaN                 NaN           NaN      NaN          NaN
# 421094          NaN                 NaN           NaN      NaN          NaN
#
#         open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  \
# 0               4.0      1271.0      55.0             34500     2.0
# 1               0.0      9358.0      87.0             23300     1.0
# 2               1.0      1959.0      66.0              5700     5.0
# 3               2.0      5268.0      88.0             23800     0.0
# 4               0.0      7494.0      80.0             30900     0.0
# ...             ...         ...       ...               ...     ...
# 421090          NaN         NaN       NaN             17100     NaN
# 421091          NaN         NaN       NaN             10200     NaN
# 421092          NaN         NaN       NaN             27000     NaN
# 421093          NaN         NaN       NaN             18000     NaN
# 421094          NaN         NaN       NaN             41700     NaN
#
#         total_cu_tl  inq_last_12m  acc_open_past_24mths  avg_cur_bal  \
# 0               1.0           2.0                     7         2014
# 1               0.0           2.0                     1        74481
# 2               0.0           3.0                     7        47670
# 3               2.0           1.0                     5        14211
# 4               0.0           0.0                     0        47745
# ...             ...           ...                   ...          ...
# 421090          NaN           NaN                     2         3159
# 421091          NaN           NaN                     3        35071
# 421092          NaN           NaN                     6         3895
# 421093          NaN           NaN                     7         3798
# 421094          NaN           NaN                     1         4163
#
#         bc_open_to_buy  bc_util  chargeoff_within_12_mths  delinq_amnt  \
# 0               5128.0     51.3                         0            0
# 1               2926.0     87.4                         0            0
# 2               2827.0     44.6                         0            0
# 3               1516.0     87.7                         0            0
# 4                  6.0     99.9                         0            0
# ...                ...      ...                       ...          ...
# 421090           448.0     95.1                         0            0
# 421091           976.0     89.2                         0            0
# 421092          3752.0     61.3                         0            0
# 421093          2554.0     75.9                         0            0
# 421094          8434.0     79.8                         0            0
#
#         mo_sin_old_il_acct  mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  \
# 0                    115.0                   112                      1
# 1                     76.0                   131                     85
# 2                    134.0                    98                     23
# 3                    112.0                   121                      4
# 4                    140.0                   267                     70
# ...                    ...                   ...                    ...
# 421090               122.0                   115                     17
# 421091                 NaN                   488                      3
# 421092                56.0                    83                      5
# 421093               134.0                   108                      6
# 421094               146.0                   155                      5
#
#         mo_sin_rcnt_tl  mort_acc  mths_since_recent_bc  \
# 0                    1         2                   9.0
# 1                    5         0                  85.0
# 2                   17         1                  23.0
# 3                    4         1                   4.0
# 4                   45         4                  99.0
# ...                ...       ...                   ...
# 421090              10         0                  90.0
# 421091               3         4                   3.0
# 421092               5         0                  12.0
# 421093               6         0                  17.0
# 421094               5         0                   5.0
#
#         mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                            NaN                    2.0
# 1                            NaN                    0.0
# 2                           29.0                    4.0
# 3                           66.0                   10.0
# 4                            NaN                    NaN
# ...                          ...                    ...
# 421090                       NaN                    9.0
# 421091                      29.0                    3.0
# 421092                       NaN                    0.0
# 421093                       NaN                   10.0
# 421094                       NaN                    0.0
#
#         mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                                  NaN                      0               6
# 1                                  NaN                      0               3
# 2                                 13.0                      1               2
# 3                                 66.0                      1               3
# 4                                 23.0                      2               1
# ...                                ...                    ...             ...
# 421090                             NaN                      0               3
# 421091                            29.0                     10               2
# 421092                             NaN                      1               5
# 421093                             NaN                      0               4
# 421094                             NaN                      0               5
#
#         num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0                    13            7          8          6             16
# 1                     3            4          4         11              4
# 2                     2            4          5         10              7
# 3                     6            4          5         13              9
# 4                     7            2          6          9              9
# ...                 ...          ...        ...        ...            ...
# 421090                6            3          4          7              7
# 421091                3            3         14          0              4
# 421092                7            7          7          3             15
# 421093                6            4          4         12              7
# 421094                5            6          7          1              6
#
#         num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0                19.0                   13        18               0.0
# 1                 4.0                    3         5               0.0
# 2                 8.0                    2        15               0.0
# 3                14.0                    7        19               0.0
# 4                20.0                    8        12               0.0
# ...               ...                  ...       ...               ...
# 421090            8.0                    6         9               0.0
# 421091           17.0                    3         5               0.0
# 421092           16.0                    7        17               0.0
# 421093           10.0                    6         9               0.0
# 421094            7.0                    5         8               0.0
#
#         num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0                  0                   0                   3           100.0
# 1                  0                   0                   1           100.0
# 2                  0                   0                   0            73.7
# 3                  0                   0                   3            96.4
# 4                  0                   1                   0            90.9
# ...              ...                 ...                 ...             ...
# 421090             0                   0                   1           100.0
# 421091             0                   0                   2            56.5
# 421092             0                   1                   2            95.0
# 421093             0                   0                   3           100.0
# 421094             0                   0                   1           100.0
#
#         percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0                   14.3                     1          0            65819
# 1                   75.0                     0          0           370357
# 2                   25.0                     0          2           704224
# 3                   75.0                     0          0           305962
# 4                  100.0                     0          0           554242
# ...                  ...                   ...        ...              ...
# 421090             100.0                     0          0            32950
# 421091             100.0                     0          0           152650
# 421092              66.7                     0          0            96919
# 421093              50.0                     1          0            51239
# 421094              50.0                     0          1            43740
#
#         total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0                   36247           10300                       31319
# 1                  372407           23300                      347057
# 2                  112166            5100                      124120
# 3                   83774           12300                       81126
# 4                   32673            7500                       10100
# ...                   ...             ...                         ...
# 421090              25274            9200                       15850
# 421091               8621            9000                           0
# 421092              58418            9700                       69919
# 421093              34178           10600                       33239
# 421094              33307           41700                           0
#
#         revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0                   NaN                     NaN                      NaN
# 1                   NaN                     NaN                      NaN
# 2                   NaN                     NaN                      NaN
# 3                   NaN                     NaN                      NaN
# 4                   NaN                     NaN                      NaN
# ...                 ...                     ...                      ...
# 421090              NaN                     NaN                      NaN
# 421091              NaN                     NaN                      NaN
# 421092              NaN                     NaN                      NaN
# 421093              NaN                     NaN                      NaN
# 421094              NaN                     NaN                      NaN
#
#         sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                            NaN                     NaN               NaN
# 1                            NaN                     NaN               NaN
# 2                            NaN                     NaN               NaN
# 3                            NaN                     NaN               NaN
# 4                            NaN                     NaN               NaN
# ...                          ...                     ...               ...
# 421090                       NaN                     NaN               NaN
# 421091                       NaN                     NaN               NaN
# 421092                       NaN                     NaN               NaN
# 421093                       NaN                     NaN               NaN
# 421094                       NaN                     NaN               NaN
#
#         sec_app_open_acc  sec_app_revol_util  sec_app_open_il_6m  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
# ...                  ...                 ...                 ...
# 421090               NaN                 NaN                 NaN
# 421091               NaN                 NaN                 NaN
# 421092               NaN                 NaN                 NaN
# 421093               NaN                 NaN                 NaN
# 421094               NaN                 NaN                 NaN
#
#         sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                         NaN                               NaN
# 1                         NaN                               NaN
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN
# ...                       ...                               ...
# 421090                    NaN                               NaN
# 421091                    NaN                               NaN
# 421092                    NaN                               NaN
# 421093                    NaN                               NaN
# 421094                    NaN                               NaN
#
#         sec_app_collections_12_mths_ex_med  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 421090                                 NaN
# 421091                                 NaN
# 421092                                 NaN
# 421093                                 NaN
# 421094                                 NaN
#
#         sec_app_mths_since_last_major_derog  fico_mean
# 0                                       NaN      667.0
# 1                                       NaN      682.0
# 2                                       NaN      682.0
# 3                                       NaN      687.0
# 4                                       NaN      667.0
# ...                                     ...        ...
# 421090                                  NaN      672.0
# 421091                                  NaN      662.0
# 421092                                  NaN      697.0
# 421093                                  NaN      682.0
# 421094                                  NaN      677.0
#
# [421095 rows x 129 columns]

# %% [markdown]
# # First model attempt

# %%
models = {}

# %%
df = df.set_index("id")

df_m1 = df[["loan_amnt", "term", "dti", "fico_mean", "grade"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-248-1a5a1af0873b> in <module>
# ----> 1 df = df.set_index("id")
#       2
#       3 df_m1 = df[["loan_amnt", "term", "dti", "fico_mean", "grade"]]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4394
#    4395         if missing:
# -> 4396             raise KeyError("None of {} are in the columns".format(missing))
#    4397
#    4398         if inplace:
#
# KeyError: "None of ['id'] are in the columns"

# %%
class_weight = class_weight.compute_class_weight("balanced", df_m1["grade"].unique(), df_m1["grade"])

# %%
#convert string variables to categorical then to integers 
def encode(df):
    
    '''
    Encoding method 2
    
    Doing 1 hot encoding on the categorical variables (except the y variable)
        @df: Dataframes with predictors X and variable y (incone)
    '''
    
    df = df.copy()
    temp = df.drop(["term"], axis = 1)
    col_cat = df[["term"]]
    
    df_dummies = pd.get_dummies(col_cat)
    
    df = pd.concat([df_dummies, temp], axis=1)
    
    return df
    
df_m1_clean_hot_method = encode(df_m1)

# %%
def train_test_split_method(df):
    '''
    Divides data into training and test set depending of the method of encoding
    
        @df_filter_students_with_income_clean_hot_method: Dataframe encoded with one hot encoding
        @df_filter_students_with_income_clean_cat_method: Dataframe encoded with cat encoding
        @hot: Boolean if hot encoding is used
    '''
    
    
    X = df.drop("grade", axis = 1)
    y = df["grade"]

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15, random_state = SEED, stratify = y)
    
    return X_train, X_test, y_train, y_test


X_train, X_test, y_train, y_test = train_test_split_method(df_m1_clean_hot_method)

# %%
#all functions to evaluate a binary model
def plot_confusion_matrix_t(y_true, y_pred,classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    Prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    
    plt.figure()
    
    
    
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    #classes = classes[unique_labels(y_true, y_pred)]
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    fig, ax = plt.subplots(figsize=(12,8))
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=classes, yticklabels=classes,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return ax

def get_features_importance(model, X):

    plt.figure()
    
    features_importance = pd.Series(model.feature_importances_, index = X.columns)

    sorted_importances_rf = features_importance.sort_values()[-10:]
  
    sorted_importances_rf.plot(kind = "barh", color = "purple")
    plt.show()
    
def get_roc_curve(model, treshold, X_val_or_test, y_val_or_test):
    
    plt.figure()
    print(treshold)
    y_pred_prob = model.predict_proba(X_val_or_test)[:, 1]
    
    fpr, tpr, tresholds = roc_curve(y_val_or_test, y_pred_prob)
    plt.plot([0, 1], [0, 1], "k--")
    plt.plot(fpr, tpr, label = "random forest")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("Random Forest ROC Curve")
    plt.show()
    
def get_classification_table(y_pred, y_val_or_test):
    
    print(classification_report(y_val_or_test, y_pred))
    
def get_recall_metrics(cm, dict_diff, letter):
    
    line = dict_diff[letter]
    
    recall = (cm[line, line]/(cm[line,:].sum())) * 100
    
    return recall

def get_fpr_metrics(cm, dict_diff, letter):
    
    line = dict_diff[letter]
    
    fpr = (cm[line, line]/(cm[:, line].sum())) * 100
    
    return fpr

def build_bar_plot(col_name, bar_height, x_label, y_label, title):
    
    bar_positions = range(len(bar_height))
    tick_positions = bar_positions
    
    if len(bar_height) > 10:
        fig, ax = plt.subplots(figsize = (15,6))
    else:
        fig, ax = plt.subplots()
        
    ax.bar(bar_positions, bar_height, 0.5)
    ax.set_xticks(tick_positions)
    ax.set_xticklabels(col_name)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.set_title(title)
    
    plt.show()
    
    
def difference_metrics(dict_diff, y_test, y_pred, incorrect_only = True):
    
    '''
    The difference metrics computes how far a preciction is from its actual value by calculating how many classes away
    the prediction is from the true value (example if predicts 300-350 and the actual value is in the next category
    350-400, then computes a difference metrics of 1)
        
        @dict_diff: The inverse of dict_y for keys and values (to be used in the different metrics function)
        @y_test: Series with the predictor variable for the test set containing all classes of income
        @y_pred: Series with the predictor variable for the training set containing all classes of income
    '''
    
    l_missclassified = []
    score_missclassified_total = 0
    
    if incorrect_only == True:
        number_missclassified = (y_test != y_pred).sum()
        #select only y points which were incorrectly predicted
        y_test_missclassified = y_test[y_test != y_pred]
        #select only y pred points whose predictions were incorrect
        y_pred_missclassified = [y_pred[i] for i in range(len(y_pred)) if (y_test.iloc[i] != y_pred[i])]
    else:
        y_test_missclassified = y_test
        y_pred_missclassified = y_pred
    
    for i in range(y_test_missclassified.size):
        
        diff_missclassified = abs(dict_diff[y_test_missclassified.iloc[i]] - dict_diff[y_pred_missclassified[i]])
        l_missclassified.append(diff_missclassified)
        score_missclassified_total += diff_missclassified
    
    score_missclassified_mean = score_missclassified_total/y_test_missclassified.size
    
    return score_missclassified_mean, l_missclassified

#l_grade = ["A", "B", "C", "D", "E", "F", "G"]
#index = list(range(len(l_grade)))

dict_diff = dict(zip(l_grade, index))
    

def evaluate_model(model, X_train, y_train, X_val_or_test, y_val_or_test, treshold = 0.5, multi_class = True):
    
    '''
    Evalutes a classification model by giving:
    - The confusion matrix
    - The accuracy score
    - The ROC curve
    - The classification table with ratios fron the confusion matrix (recall, precisions etc...)
    - The most important features from the model
    
        @model: Model used
        @X_train: X training data with predictors already encoded
        @X_val_or_test: X test data with predictors already encoded
        @y_train: Series with the predictor variable for the training set containing all classes of income
        @y_test: Series with the predictor variable for the test set containing all classes of income
        @treshold: probability rate at which we decide if an observation takes value 1 or 0
        @multi_class: True if multi class model in y, False if binary classifier
    '''
    
    y_pred_prob = model.predict_proba(X_val_or_test)[:, 1] >= treshold
    y_pred = model.predict(X_test)
    y_pred_train = model.predict(X_train)
    
    l_grade = np.sort(y_val_or_test.unique())
    index = range(len(l_grade))
    
    dict_diff = dict(zip(l_grade, index))
    
    
    if multi_class == True:
        cm = confusion_matrix(y_val_or_test, y_pred)
        
        #get confusion matrix
        plot_confusion_matrix_t(y_val_or_test, y_pred, l_grade)
        
        #get recall score
        l_recall_score = []
        for i in l_grade:
            l_recall_score.append(get_recall_metrics(cm, dict_diff, i))
        
        build_bar_plot(l_grade, 
                       l_recall_score, 
                       "Grades", 
                       "Recall score", 
                       "Recall score for each grade")
        
        #get fpr score
        l_fpr_score = []
        for i in l_grade:
            l_fpr_score.append(get_fpr_metrics(cm, dict_diff, i))
        
        build_bar_plot(l_grade, 
                       l_fpr_score, 
                       "Grades", 
                       "FPR score", 
                       "FPR score for each grade")
        
        #get accuracy score
        print("accuracy_score is ", accuracy_score(y_val_or_test, y_pred))
        
        #get difference metrics 
        difference_metrics_score, l_score = difference_metrics(dict_diff, y_val_or_test, y_pred, incorrect_only = False)
        print("difference metrics score is ", difference_metrics_score)
        
        
        
    else:
        plot_confusion_matrix_t(y_val_or_test, y_pred_prob, classes= np.array([0, 1]),
                      title='confusion matrix')
        get_roc_curve(model, treshold, X_val_or_test, y_val_or_test)
    
        get_classification_table(y_pred_prob, y_val_or_test)
        
        print("recall on test set is ", recall_score(y_val_or_test, y_pred))
        print("recall on training set is ", recall_score(y_train, y_pred_train))
    
    #get feature importance
    get_features_importance(model, X_test)

# %%
rf = RandomForestClassifier(random_state = SEED, class_weight = "balanced", max_depth = 20, min_samples_split = 50)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight='balanced',
#                        criterion='gini', max_depth=20, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=50,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
y_pred = rf.predict(X_test)

accuracy_score(y_test, y_pred)
# Out:
# 0.35375603577930814

# %%
evaluate_model(rf, X_train, y_train, X_test, y_test)
# Out:
# Confusion matrix, without normalization
# [[8029 2157  502  188   75   36   14]
#  [4950 6799 2709 1355 1086  590  152]
#  [2592 4939 3322 2531 2751 1501  449]
#  [ 807 1641 1333 1973 2015 1293  336]
#  [ 214  517  424  785 1628 1295  379]
#  [  27   98   73  123  442  539  171]
#  [   2   22   13   25   86  122   55]]
# accuracy_score is  0.35375603577930814
# difference metrics score is  1.0508509459352489

# %%
score, l = difference_metrics(dict_diff, y_test, y_pred, incorrect_only = False)

# %%
score
# Out:
# 1.0508509459352489

# %%
models["rf_class_weight_max_depth_20"] = rf

# %% [markdown]
# # Attempt to equilibrate the model

# %%
df_m2 = df[["loan_amnt", "term", "dti", "fico_mean", "grade"]]

# %%
df_m2_hot_method = encode(df_m2)

# %%
X_train, X_test, y_train, y_test = train_test_split_method(df_m2_hot_method)

# %%
df_m2_train_all = pd.concat([X_train, y_train], axis = 1)

# %%
def rebalance_data(df, max_rows_per_grade = 8000):
    
    n_rows_per_grade = df.shape[0]
        
    if n_rows_per_grade > max_rows_per_grade:
        
        random_rows = random.sample(range(n_rows_per_grade), max_rows_per_grade)
        
        df = df.iloc[random_rows, :]
    
    return df

# %%
df_m2_train = df_m2_train_all.groupby("grade").apply(lambda x: rebalance_data(x))
df_m2_train = df_m2_train.reset_index(drop = True)

# %%
X_train, X_val, y_train, y_val = train_test_split_method(df_m2_train)

# %%
rf = RandomForestClassifier(random_state = SEED)

rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
#validation score
y_pred = rf.predict(X_val)

print(accuracy_score(y_val, y_pred))
confusion_matrix(y_val, y_pred)
# Out:
# 0.3113548214524542
# array([[753, 234, 128,  62,  16,   6,   1],
#        [306, 346, 222, 163,  83,  75,   5],
#        [188, 269, 257, 208, 140, 127,  11],
#        [102, 204, 228, 243, 215, 187,  21],
#        [ 49, 143, 176, 216, 304, 281,  31],
#        [ 20,  88, 141, 183, 304, 413,  51],
#        [  7,  21,  24,  40,  65, 108,  12]])

# %%
#test_score

# %%
y_val.value_counts()
# Out:
# F    1200
# B    1200
# D    1200
# A    1200
# C    1200
# E    1200
# G     277
# Name: grade, dtype: int64
